# %%
import os;os.chdir('/content/drive/My Drive/Colab Notebooks/Lazy courses/NLP2')

# %%
import os
import json
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD

from datetime import datetime
from sklearn.utils import shuffle
from utils import find_analogies


import sys

from utils import get_wikipedia_data
from brown import get_sentences_with_word2idx_limit_vocab, get_sentences_with_word2idx

# %%
class Glove:
    def __init__(self, D, V, context_sz):
        self.D = D
        self.V = V
        self.context_sz = context_sz

    def fit(self, sentences, cc_matrix=None):
        # build co-occurrence matrix
        # paper calls it X, so we will call it X, instead of calling
        # the training data X
        # TODO: would it be better to use a sparse matrix?

        t0 = datetime.now()
        V = self.V
        D = self.D

        if not os.path.exists(cc_matrix):
            X = np.zeros((V,V))
            N = len(sentences)
            print("Number of sentences to process", N)
            it = 0
            for sentence in sentences:
                it += 1
                if it % 10000 == 0:
                    print('Processed:', it, '/', N)

                n = len(sentence)
                for i in range(n):
                    # i is not the word index!!!
                    # j is not the word index!!!
                    # i just points to which element of the sequence (sentence) we're looking at
                    wi = sentence[i]

                    start = max(0, i - self.context_sz)
                    end = min(n, i + self.context_sz)   
                    # we can either choose only one side as context, or both
                    # here we are doing both

                    # make sure "start" and "end" tokens are part of some context
                    # otherwise their f(X) will be 0 (denominator in bias update)

                    if i - self.context_sz < 0:
                        points = 1.0 / (i + 1)
                        X[wi,0] += points
                        X[0,wi] += points
                    if i + self.context_sz > n:
                        points = 1.0 / (n - i)
                        X[wi,1] += points
                        X[1,wi] += points

                    # left side
                    for j in range(start, i):
                        wj = sentence[j]
                        points = 1.0 / (i - j) # this is +ve
                        X[wi,wj] += points
                        X[wj,wi] += points

                    # right side
                    for j in range(i + 1, end):
                        wj = sentence[j]
                        points = 1.0 / (j - i) # this is +ve
                        X[wi,wj] += points
                        X[wj,wi] += points 

            # save the cc matrix because it takes forever to create
            np.save(cc_matrix, X)
        else:
            X = np.load(cc_matrix)


        print("max in X:", X.max())

        # target
        logX = np.log(X + 1)

        print("max in log(X):", logX.max())

        print("time to build co-occurrence matrix:", (datetime.now() - t0))

        # subtract global mean
        mu = logX.mean()

        model = TruncatedSVD(n_components=D)
        Z = model.fit_transform(logX - mu)
        S = np.diag(model.explained_variance_)
        Sinv = np.linalg.inv(S)
        self.W = Z.dot(Sinv)
        self.U = model.components_.T

        #calculate cost once
        delta = self.W.dot(S).dot(self.U.T) + mu - logX
        cost = (delta * delta).sum()
        print("SVD cost", cost)


    def save(self, fn):
        # function word_analogies expects a (V,D) matrx and a (D,V) matrix
        arrays = [self.W, self.U.T]
        np.savez(fn, *arrays)

# %%
def main(we_file, w2i_file, use_brown=True, n_files=100):
    if use_brown:
        cc_matrix = "cc_matrix_brown.npy"
    else:
        cc_matrix = "cc_matrix_%s_svd.npy" % n_files

    # hacky way of checking if we need to re-load the raw data or not
    # remember, only the co-occurrence matrix is needed for training
    if os.path.exists(cc_matrix):
        with open(w2i_file) as f:
            word2idx = json.load(f)
        sentences = [] # dummy - we won't actually use it
    else:
        if use_brown:
            keep_words = set([
                'king', 'man', 'woman',
                'france', 'paris', 'london', 'rome', 'italy', 'britain', 'england',
                'french', 'english', 'japan', 'japanese', 'chinese', 'italian',
                'australia', 'australian', 'december', 'november', 'june',
                'january', 'february', 'march', 'april', 'may', 'july', 'august',
                'september', 'october',
            ])
            sentences, word2idx = get_sentences_with_word2idx_limit_vocab(n_vocab=5000, keep_words=keep_words)
        else:
            sentences, word2idx = get_wikipedia_data(n_files=n_files, n_vocab=2000)
        
        with open(w2i_file, 'w') as f:
            json.dump(word2idx, f)

    V = len(word2idx)
    model = Glove(100, V, 10)

    # alternating least squares method
    model.fit(sentences, cc_matrix=cc_matrix)
    model.save(we_file)

# %%
if __name__ == '__main__':
    we = 'glove_svd_50.npz'
    w2i = 'glove_word2idx_50.json'
    # we = 'glove_svd_brown.npz'
    # w2i = 'glove_word2idx_brown.json'
    main(we, w2i, use_brown=False)
    
    # load back embeddings
    npz = np.load(we)
    W1 = npz['arr_0']
    W2 = npz['arr_1']

    with open(w2i) as f:
        word2idx = json.load(f)
        idx2word = {i:w for w,i in word2idx.items()}

    for concat in (True, False):
        print("** concat:", concat)

        if concat:
            We = np.hstack([W1, W2.T])
        else:
            We = (W1 + W2.T) / 2


        find_analogies('king', 'man', 'woman', We, word2idx, idx2word)
        find_analogies('france', 'paris', 'london', We, word2idx, idx2word)
        find_analogies('france', 'paris', 'rome', We, word2idx, idx2word)
        find_analogies('paris', 'france', 'italy', We, word2idx, idx2word)
        find_analogies('france', 'french', 'english', We, word2idx, idx2word)
        find_analogies('japan', 'japanese', 'chinese', We, word2idx, idx2word)
        find_analogies('japan', 'japanese', 'italian', We, word2idx, idx2word)
        find_analogies('japan', 'japanese', 'australian', We, word2idx, idx2word)
        find_analogies('december', 'november', 'june', We, word2idx, idx2word)
# Out:
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-01.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-02.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-03.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-04.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-05.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-06.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-07.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-08.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-09.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-10.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-11.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-12.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-13.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-14.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-15.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-16.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-17.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-18.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-19.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-20.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-21.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-22.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-23.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-24.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-25.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-26.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-27.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-28.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-29.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-30.txt
# reading: enwiki-20180401-pages-articles1.xml-p10p30302-31.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-01.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-34.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-35.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-36.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-37.txt
# reading: enwiki-20180620-pages-articles2.xml-p30304p88444-38.txt
# START inf
# END inf
# the 6472843
# of 3272165
# and 2543432
# in 2386722
# to 1922734
# a 1787922
# is 858341
# was 832602
# as 808298
# for 699829
# by 659662
# that 648285
# with 621284
# on 578040
# from 455933
# his 397706
# it 387881
# are 387273
# at 358558
# an 342463
# he 340520
# or 335458
# which 320612
# be 312808
# were 306057
# this 279552
# not 223505
# had 221970
# also 221144
# have 213330
# has 204457
# their 197821
# but 193539
# its 190315
# one 181645
# first 172687
# other 166529
# they 164720
# been 159818
# who 146958
# after 146242
# new 142787
# such 139564
# more 136502
# two 129256
# when 128739
# some 128089
# most 128045
# all 126834
# used 124445
# into 122946
# can 122532
# there 116483
# during 113252
# time 111206
# may 110744
# many 108887
# than 107326
# would 106754
# these 106409
# only 105936
# between 100396
# her 97418
# complete 11469
# met 11463
# v 11463
# highest 11457
# previous 11439
# 14 11434
# nearly 11422
# opened 11410
# academy 11408
# need 11395
# direct 11390
# campaign 11389
# parliament 11384
# 2002 11377
# smaller 11375
# give 11360
# police 11360
# percent 11355
# separate 11345
# idea 11341
# claimed 11326
# african 11313
# 2017 11308
# sources 11303
# better 11299
# money 11297
# daughter 11289
# regions 11289
# access 11282
# oil 11253
# authority 11247
# worked 11240
# 19th 11239
# ground 11232
# reached 11231
# supported 11219
# medical 11191
# board 11174
# 2003 11165
# largely 11157
# create 11121
# paul 11097
# levels 11089
# additional 11078
# our 11068
# likely 11049
# entire 11038
# placed 11012
# operations 11005
# true 10955
# allow 10948
# leader 10935
# financial 10925
# products 10924
# nuclear 10902
# relationship 10899
# troops 10892
# active 10890
# programs 10871
# ten 10859
# temperature 10855
# square 10848
# problem 10828
# 13 10819
# organization 10816
# changed 10784
# louis 10783
# rest 10781
# constitution 10776
# joined 10766
# rome 10763
# km 10749
# concept 10726
# 20th 10713
# enough 10709
# peace 10659
# status 10657
# songs 10657
# decided 10656
# congress 10643
# initially 10640
# green 10590
# forced 10550
# training 10547
# artists 10540
# finally 10538
# highly 10537
# chief 10531
# eight 10530
# move 10524
# yet 10516
# individuals 10486
# get 10471
# completed 10470
# 24 10468
# grand 10450
# deaths 10441
# port 10402
# shown 10398
# contains 10390
# taking 10382
# gas 10376
# response 10370
# report 10370
# plan 10367
# amount 10348
# divided 10339
# places 10330
# speed 10329
# attempt 10325
# adopted 10320
# multiple 10320
# buildings 10311
# blue 10307
# director 10306
# laws 10295
# unit 10287
# kings 10285
# pope 10283
# scientific 10279
# treaty 10270
# turn 10268
# spain 10257
# appears 10248
# richard 10242
# discovered 10240
# whole 10237
# cannot 10231
# past 10227
# prior 10220
# 1999 10218
# thomas 10217
# classical 10205
# independence 10203
# test 10185
# relations 10175
# letter 10172
# appear 10149
# appointed 10139
# noted 10134
# section 10117
# brother 10103
# billion 10098
# sports 10092
# dutch 10092
# 9 10086
# find 10081
# wide 10077
# iii 10073
# signed 10062
# operation 10061
# starting 10061
# estimated 10053
# previously 10049
# examples 10037
# tradition 10028
# mainly 10023
# me 10023
# washington 10005
# peoples 9988
# behind 9985
# date 9975
# 50 9966
# currently 9936
# committee 9923
# bank 9916
# passed 9906
# blood 9906
# color 9892
# probably 9887
# article 9886
# issue 9877
# metal 9873
# primarily 9864
# basis 9863
# child 9850
# refer 9847
# regular 9804
# collection 9803
# done 9799
# featured 9796
# length 9790
# province 9788
# 17 9786
# ended 9765
# ships 9755
# arts 9751
# navy 9750
# valley 9739
# relatively 9734
# basic 9713
# playing 9712
# marriage 9709
# property 9696
# older 9688
# asia 9680
# location 9655
# makes 9623
# methods 9613
# revolution 9600
# latter 9593
# sense 9575
# religion 9553
# tour 9551
# difficult 9544
# f 9541
# compared 9539
# rules 9538
# race 9535
# queen 9528
# 1998 9526
# frequently 9508
# text 9500
# loss 9498
# parties 9493
# stories 9492
# issues 9479
# conference 9463
# provides 9461
# s 9442
# animals 9440
# fall 9435
# agreement 9435
# administration 9432
# carried 9430
# russia 9420
# simply 9405
# product 9392
# suggested 9392
# heavy 9378
# centuries 9376
# institute 9375
# income 9372
# stars 9338
# start 9336
# regional 9328
# lack 9326
# fiction 9326
# canadian 9317
# 1980s 9315
# worlds 9310
# knowledge 9300
# hours 9293
# experience 9289
# festival 9277
# disease 9274
# n 9264
# literature 9244
# saint 9244
# functions 9239
# democratic 9229
# resulting 9226
# annual 9219
# e 9219
# analysis 9217
# command 9204
# prince 9198
# lord 9193
# intended 9189
# feature 9188
# simple 9185
# cost 9173
# news 9170
# sun 9160
# bridge 9160
# israel 9157
# 1970s 9153
# applied 9152
# birth 9118
# library 9111
# treatment 9099
# potential 9091
# airport 9087
# big 9055
# notable 9053
# upper 9043
# ireland 9041
# failed 9030
# industrial 9029
# 21 9015
# ie 8982
# calendar 8974
# professional 8973
# memory 8948
# account 8938
# management 8935
# cells 8925
# plants 8915
# route 8914
# fourth 8896
# accepted 8894
# families 8894
# lived 8890
# urban 8886
# here 8882
# except 8874
# vote 8843
# ability 8834
# plant 8829
# 1997 8826
# becoming 8812
# 1960s 8807
# quickly 8788
# 1996 8787
# activity 8782
# border 8778
# ad 8777
# objects 8770
# degree 8765
# theatre 8730
# image 8725
# powers 8721
# declared 8720
# jews 8706
# approach 8703
# climate 8699
# directed 8693
# woman 8689
# winter 8675
# press 8672
# reduced 8671
# composed 8665
# mission 8665
# global 8664
# win 8653
# offered 8639
# bill 8630
# magazine 8629
# governor 8627
# d 8621
# course 8612
# 22 8610
# australian 8590
# soldiers 8586
# assembly 8581
# irish 8571
# exist 8569
# actually 8567
# extended 8562
# operating 8560
# peter 8556
# presence 8535
# influenced 8529
# transport 8526
# matter 8521
# running 8517
# machine 8513
# reference 8510
# chemical 8508
# los 8506
# scholars 8497
# occur 8493
# letters 8488
# remain 8469
# remaining 8453
# bay 8450
# initial 8437
# internet 8431
# combined 8431
# takes 8431
# 1990s 8428
# agreed 8428
# wars 8422
# activities 8421
# models 8413
# quality 8412
# cup 8401
# turned 8391
# clear 8391
# responsible 8390
# engine 8386
# origin 8382
# imperial 8382
# distance 8376
# paper 8368
# derived 8362
# stone 8346
# r 8345
# rise 8342
# holy 8336
# bands 8315
# car 8310
# ones 8301
# edward 8301
# increasing 8294
# read 8282
# represented 8282
# commission 8268
# wanted 8255
# 1992 8253
# argued 8241
# dead 8236
# defense 8232
# reason 8230
# claim 8220
# speech 8210
# asked 8208
# hit 8207
# 1995 8207
# mark 8204
# consists 8184
# 1994 8175
# decision 8175
# 23 8138
# direction 8137
# pacific 8135
# elections 8135
# element 8134
# medieval 8126
# appearance 8122
# claims 8119
# michael 8114
# census 8107
# risk 8106
# launched 8103
# necessary 8102
# poor 8088
# greatest 8086
# resulted 8079
# exchange 8079
# told 8049
# tax 8044
# ship 8042
# leaders 8040
# philosophy 8023
# channel 8010
# stations 8004
# 1990 8004
# opposition 8003
# polish 8002
# identified 8000
# 19 7999
# spread 7995
# notes 7986
# contemporary 7978
# critical 7977
# p 7976
# nation 7975
# heart 7972
# environment 7953
# workers 7936
# railway 7936
# things 7920
# subsequently 7918
# plays 7918
# creation 7918
# acid 7916
# immediately 7916
# 1991 7909
# 1978 5316
# safety 5313
# goods 5312
# administrative 5299
# newly 5296
# wood 5291
# technique 5291
# columbia 5288
# theories 5281
# roughly 5280
# break 5278
# combat 5264
# steel 5255
# iv 5255
# l 5247
# gain 5246
# williams 5246
# provinces 5244
# similarly 5242
# succeeded 5237
# score 5237
# facilities 5230
# file 5230
# radiation 5227
# widespread 5224
# greatly 5224
# mount 5224
# 1965 5221
# supporting 5220
# camp 5217
# count 5217
# christ 5215
# roles 5213
# producing 5213
# 1960 5212
# lee 5212
# external 5211
# online 5209
# causing 5205
# format 5204
# ages 5203
# seats 5196
# brain 5192
# formula 5192
# purposes 5192
# limit 5188
# greece 5185
# 1977 5183
# think 5181
# mathematics 5179
# protect 5178
# engines 5176
# user 5174
# spoken 5172
# tribes 5166
# 1966 5165
# spirit 5164
# stock 5161
# search 5158
# pattern 5156
# bbc 5156
# seems 5155
# why 5151
# bus 5148
# computers 5139
# texts 5136
# rural 5135
# decade 5120
# jersey 5116
# useful 5114
# demand 5097
# master 5096
# featuring 5094
# contributed 5092
# manager 5090
# flag 5087
# crew 5086
# agriculture 5082
# adapted 5077
# newspaper 5074
# 20thcentury 5070
# indigenous 5069
# translation 5067
# concluded 5066
# soil 5064
# influential 5062
# learning 5055
# begin 5052
# titles 5052
# olympic 5052
# inhabitants 5049
# musicians 5048
# drug 5046
# bowl 5045
# headquarters 5040
# images 5040
# Number of sentences to process 3919459
# Processed: 10000 / 3919459
# Processed: 20000 / 3919459
# Processed: 30000 / 3919459
# Processed: 40000 / 3919459
# Processed: 50000 / 3919459
# Processed: 60000 / 3919459
# Processed: 70000 / 3919459
# Processed: 80000 / 3919459
# Processed: 90000 / 3919459
# Processed: 100000 / 3919459
# Processed: 110000 / 3919459
# Processed: 120000 / 3919459
# Processed: 130000 / 3919459
# Processed: 140000 / 3919459
# Processed: 150000 / 3919459
# Processed: 160000 / 3919459
# Processed: 170000 / 3919459
# Processed: 180000 / 3919459
# Processed: 190000 / 3919459
# Processed: 200000 / 3919459
# Processed: 210000 / 3919459
# Processed: 220000 / 3919459
# Processed: 230000 / 3919459
# Processed: 240000 / 3919459
# Processed: 250000 / 3919459
# Processed: 260000 / 3919459
# Processed: 270000 / 3919459
# Processed: 280000 / 3919459
# Processed: 290000 / 3919459
# Processed: 300000 / 3919459
# Processed: 310000 / 3919459
# Processed: 320000 / 3919459
# Processed: 330000 / 3919459
# Processed: 340000 / 3919459
# Processed: 350000 / 3919459
# Processed: 360000 / 3919459
# Processed: 370000 / 3919459
# Processed: 380000 / 3919459
# Processed: 390000 / 3919459
# Processed: 400000 / 3919459
# Processed: 410000 / 3919459
# Processed: 420000 / 3919459
# Processed: 430000 / 3919459
# Processed: 440000 / 3919459
# Processed: 450000 / 3919459
# Processed: 460000 / 3919459
# Processed: 470000 / 3919459
# Processed: 480000 / 3919459
# Processed: 490000 / 3919459
# Processed: 500000 / 3919459
# Processed: 510000 / 3919459
# Processed: 520000 / 3919459
# Processed: 530000 / 3919459
# Processed: 540000 / 3919459
# Processed: 550000 / 3919459
# Processed: 560000 / 3919459
# Processed: 570000 / 3919459
# Processed: 580000 / 3919459
# Processed: 3590000 / 3919459
# Processed: 3600000 / 3919459
# Processed: 3610000 / 3919459
# Processed: 3620000 / 3919459
# Processed: 3630000 / 3919459
# Processed: 3640000 / 3919459
# Processed: 3650000 / 3919459
# Processed: 3660000 / 3919459
# Processed: 3670000 / 3919459
# Processed: 3680000 / 3919459
# Processed: 3690000 / 3919459
# Processed: 3700000 / 3919459
# Processed: 3710000 / 3919459
# Processed: 3720000 / 3919459
# Processed: 3730000 / 3919459
# Processed: 3740000 / 3919459
# Processed: 3750000 / 3919459
# Processed: 3760000 / 3919459
# Processed: 3770000 / 3919459
# Processed: 3780000 / 3919459
# Processed: 3790000 / 3919459
# Processed: 3800000 / 3919459
# Processed: 3810000 / 3919459
# Processed: 3820000 / 3919459
# Processed: 3830000 / 3919459
# Processed: 3840000 / 3919459
# Processed: 3850000 / 3919459
# Processed: 3860000 / 3919459
# Processed: 3870000 / 3919459
# Processed: 3880000 / 3919459
# Processed: 3890000 / 3919459
# Processed: 3900000 / 3919459
# Processed: 3910000 / 3919459
# max in X: 75446433.19263569
# max in log(X): 18.138933481526337
# time to build co-occurrence matrix: 0:22:56.376894
# SVD cost 858076.9130666372
# ** concat: True
# Closest match by euclidean distance: queen
# king - man = queen - woman
# Closest match by cosine distance: queen
# king - man = queen - woman
# Closest match by euclidean distance: britain
# france - paris = britain - london
# Closest match by cosine distance: britain
# france - paris = britain - london
# Closest match by euclidean distance: italy
# france - paris = italy - rome
# Closest match by cosine distance: greece
# france - paris = greece - rome
# Closest match by euclidean distance: rome
# paris - france = rome - italy
# Closest match by cosine distance: rome
# paris - france = rome - italy
# Closest match by euclidean distance: england
# france - french = england - english
# Closest match by cosine distance: england
# france - french = england - english
# Closest match by euclidean distance: china
# japan - japanese = china - chinese
# Closest match by cosine distance: china
# japan - japanese = china - chinese
# Closest match by euclidean distance: italy
# japan - japanese = italy - italian
# Closest match by cosine distance: italy
# japan - japanese = italy - italian
# Closest match by euclidean distance: australia
# japan - japanese = australia - australian
# Closest match by cosine distance: australia
# japan - japanese = australia - australian
# Closest match by euclidean distance: january
# december - november = january - june
# Closest match by cosine distance: january
# december - november = january - june
# ** concat: False
# Closest match by euclidean distance: queen
# king - man = queen - woman
# Closest match by cosine distance: queen
# king - man = queen - woman
# Closest match by euclidean distance: britain
# france - paris = britain - london
# Closest match by cosine distance: britain
# france - paris = britain - london
# Closest match by euclidean distance: italy
# france - paris = italy - rome
# Closest match by cosine distance: italy
# france - paris = italy - rome
# Closest match by euclidean distance: rome
# paris - france = rome - italy
# Closest match by cosine distance: rome
# paris - france = rome - italy
# Closest match by euclidean distance: england
# france - french = england - english
# Closest match by cosine distance: england
# france - french = england - english
# Closest match by euclidean distance: china
# japan - japanese = china - chinese
# Closest match by cosine distance: china
# japan - japanese = china - chinese
# Closest match by euclidean distance: italy
# japan - japanese = italy - italian
# Closest match by cosine distance: italy
# japan - japanese = italy - italian
# Closest match by euclidean distance: australia
# japan - japanese = australia - australian
# Closest match by cosine distance: australia
# japan - japanese = australia - australian
# Closest match by euclidean distance: january
# december - november = january - june
# Closest match by cosine distance: january
# december - november = january - june
