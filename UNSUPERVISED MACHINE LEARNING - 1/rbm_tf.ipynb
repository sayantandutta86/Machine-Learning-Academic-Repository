# %%
import os; os.chdir('/content/drive/My Drive/Colab Notebooks/Lazy courses/Unsupervised Learning')

# %%
import numpy as np
import matplotlib.pyplot as plt
# %tensorflow_version 1.x
import tensorflow as tf
from sklearn.utils import shuffle
from util import getKaggleMNIST
from autoencoder_tf import DNN
# Out:
# TensorFlow 1.x selected.

# %%
class RBM(object):
    def __init__(self, D, M, an_id):
        self.D = D
        self.M = M
        self.id = an_id
        self.build(D,M)

    def set_session(self, session):
        self.session = session

    def build(self, D, M):
        #params
        self.W = tf.Variable(tf.random_normal(shape=(D, M)) * np.sqrt(2.0 / M))
        #without limiting variance we may get numerical staiblity issues
        self.c = tf.Variable(np.zeros(M).astype(np.float32))
        self.b = tf.Variable(np.zeros(D).astype(np.float32))

        #data
        self.X_in = tf.placeholder(tf.float32, shape = (None, D))

        #conditional probabilities
        V = self.X_in
        p_h_given_v = tf.nn.sigmoid(tf.matmul(V, self.W) + self.c)
        self.p_h_given_v = p_h_given_v #save the variable for later
        r = tf.random_uniform(shape=tf.shape(p_h_given_v))
        H = tf.to_float(r < p_h_given_v) #convert probability to bernouilli binary values

        p_v_given_h = tf.nn.sigmoid(tf.matmul(H, tf.transpose(self.W)) + self.b)
        r = tf.random_uniform(shape=tf.shape(p_v_given_h))
        X_sample = tf.to_float(r < p_v_given_h)

        #build the objective function
        objective = tf.reduce_mean(self.free_energy(self.X_in)) - tf.reduce_mean(self.free_energy(X_sample))
        self.train_op = tf.train.AdamOptimizer(1e-2).minimize(objective)
        # self.train_op = tf.train.GradientDescentOptimizer(1e-3).minimize(objective)

        #build the cost
        #we won't use this to optimize the model parameters
        #just to observe what happens during training
        logits = self.forward_logits(self.X_in)
        self.cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=self.X_in, logits=logits))

    def fit(self, X, epochs=1, batch_sz=100, show_fig=False):
        N, D = X.shape
        n_batches = N // batch_sz
        
        costs = []
        print("Training rbm: %s" %self.id)
        for i in range(epochs):
            print("epoch:", i)
            X = shuffle(X)
            for j in range(n_batches):
                batch = X[j*batch_sz: (j*batch_sz + batch_sz)]
                _, c = self.session.run((self.train_op, self.cost), feed_dict={self.X_in: batch})
                if j % 10 == 0:
                    print("j / n_batches:", j, "/", n_batches, "cost:", c)
                costs.append(c)
        if show_fig:
            plt.plot(costs)
            plt.show()

    def free_energy(self, V):
        b = tf.reshape(self.b, (self.D, 1))
        first_term = -tf.matmul(V, b)
        first_term = tf.reshape(first_term, (-1,))

        second_term = -tf.reduce_sum(tf.nn.softplus(tf.matmul(V, self.W) + self.c), axis=1)

        return first_term + second_term



    def forward_hidden(self, X):
        return tf.nn.sigmoid(tf.matmul(X, self.W) + self.c)

    def forward_logits(self, X):
        Z = self.forward_hidden(X)
        return tf.matmul(Z, tf.transpose(self.W) + self.b) 

    def forward_output(self, X):
        return tf.nn.sigmoid(self.forward_logits(X))

    def transform(self, X):
        # accepts and returns a real numpy array
        # unlike forward_hidden and forward_output
        # which deal with tensorflow variables
        return self.session.run(self.p_h_given_v, feed_dict={self.X_in:X})

def main():
    Xtrain, Ytrain, Xtest, Ytest = getKaggleMNIST()

    #same as autoencoder_tf.py
    Xtrain = Xtrain.astype(np.float32)
    Xtest = Xtest.astype(np.float32)
    _, D = Xtrain.shape
    K = len(set(Ytrain))
    dnn = DNN(D, [1000, 750, 500], K, UnsupervisedModel=RBM)
    init_op = tf.global_variables_initializer()
    with tf.Session() as session:
        session.run(init_op)
        dnn.set_session(session)
        dnn.fit(Xtrain, Ytrain, Xtest, Ytest, pretrain=True, epochs=10)

# %%
if __name__ == "__main__":
    main()
# Out:
# Training rbm: 0
# epoch: 0
# j / n_batches: 0 / 590 cost: 0.7305746
# j / n_batches: 10 / 590 cost: 0.3374709
# j / n_batches: 20 / 590 cost: 0.4312332
# j / n_batches: 30 / 590 cost: 0.4176904
# j / n_batches: 40 / 590 cost: 0.40737948
# j / n_batches: 50 / 590 cost: 0.40476626
# j / n_batches: 60 / 590 cost: 0.38575333
# j / n_batches: 70 / 590 cost: 0.38842478
# j / n_batches: 80 / 590 cost: 0.35333735
# j / n_batches: 90 / 590 cost: 0.3663307
# j / n_batches: 100 / 590 cost: 0.37552476
# j / n_batches: 110 / 590 cost: 0.37120315
# j / n_batches: 120 / 590 cost: 0.38037813
# j / n_batches: 130 / 590 cost: 0.39259654
# j / n_batches: 140 / 590 cost: 0.38630888
# j / n_batches: 150 / 590 cost: 0.40002924
# j / n_batches: 160 / 590 cost: 0.42166573
# j / n_batches: 170 / 590 cost: 0.41255713
# j / n_batches: 180 / 590 cost: 0.44166464
# j / n_batches: 190 / 590 cost: 0.48479447
# j / n_batches: 200 / 590 cost: 0.49563566
# j / n_batches: 210 / 590 cost: 0.53925216
# j / n_batches: 220 / 590 cost: 0.5067409
# j / n_batches: 230 / 590 cost: 0.5519302
# j / n_batches: 240 / 590 cost: 0.58247465
# j / n_batches: 250 / 590 cost: 0.59901625
# j / n_batches: 260 / 590 cost: 0.57095814
# j / n_batches: 270 / 590 cost: 0.6666926
# j / n_batches: 280 / 590 cost: 0.65353394
# j / n_batches: 290 / 590 cost: 0.7148664
# j / n_batches: 300 / 590 cost: 0.72799605
# j / n_batches: 310 / 590 cost: 0.7490031
# j / n_batches: 320 / 590 cost: 0.7547133
# j / n_batches: 330 / 590 cost: 0.85390264
# j / n_batches: 340 / 590 cost: 0.8262429
# j / n_batches: 350 / 590 cost: 0.84429866
# j / n_batches: 360 / 590 cost: 0.94649315
# j / n_batches: 370 / 590 cost: 0.88859695
# j / n_batches: 380 / 590 cost: 0.95738304
# j / n_batches: 390 / 590 cost: 0.95680165
# j / n_batches: 400 / 590 cost: 0.9637561
# j / n_batches: 410 / 590 cost: 1.0597407
# j / n_batches: 420 / 590 cost: 1.0314763
# j / n_batches: 430 / 590 cost: 1.1057903
# j / n_batches: 440 / 590 cost: 1.0960108
# j / n_batches: 450 / 590 cost: 1.0870748
# j / n_batches: 460 / 590 cost: 1.1193928
# j / n_batches: 470 / 590 cost: 1.2001911
# j / n_batches: 480 / 590 cost: 1.24246
# j / n_batches: 490 / 590 cost: 1.193637
# j / n_batches: 500 / 590 cost: 1.2895566
# j / n_batches: 510 / 590 cost: 1.3449959
# j / n_batches: 520 / 590 cost: 1.3869278
# j / n_batches: 530 / 590 cost: 1.4020748
# j / n_batches: 540 / 590 cost: 1.39665
# j / n_batches: 550 / 590 cost: 1.5102688
# j / n_batches: 560 / 590 cost: 1.4714401
# j / n_batches: 570 / 590 cost: 1.4597456
# j / n_batches: 580 / 590 cost: 1.4581532
# Training rbm: 1
# epoch: 0
# j / n_batches: 0 / 590 cost: 0.73273015
# j / n_batches: 10 / 590 cost: 0.40384376
# j / n_batches: 20 / 590 cost: 0.72146267
# j / n_batches: 30 / 590 cost: 1.3159709
# j / n_batches: 40 / 590 cost: 1.8333434
# j / n_batches: 50 / 590 cost: 2.4330852
# j / n_batches: 60 / 590 cost: 2.736857
# j / n_batches: 70 / 590 cost: 2.963022
# j / n_batches: 80 / 590 cost: 2.9999158
# j / n_batches: 90 / 590 cost: 3.2032177
# j / n_batches: 100 / 590 cost: 3.3686132
# j / n_batches: 110 / 590 cost: 3.36374
# j / n_batches: 120 / 590 cost: 3.370076
# j / n_batches: 130 / 590 cost: 3.4814782
# j / n_batches: 140 / 590 cost: 3.4281526
# j / n_batches: 150 / 590 cost: 3.4805875
# j / n_batches: 160 / 590 cost: 3.4432037
# j / n_batches: 170 / 590 cost: 3.5366178
# j / n_batches: 180 / 590 cost: 3.5363512
# j / n_batches: 190 / 590 cost: 3.6123128
# j / n_batches: 200 / 590 cost: 3.5801818
# j / n_batches: 210 / 590 cost: 3.5577588
# j / n_batches: 220 / 590 cost: 3.6248922
# j / n_batches: 230 / 590 cost: 3.6033418
# j / n_batches: 240 / 590 cost: 3.700985
# j / n_batches: 250 / 590 cost: 3.5634394
# j / n_batches: 260 / 590 cost: 3.6185007
# j / n_batches: 270 / 590 cost: 3.5236113
# j / n_batches: 280 / 590 cost: 3.5036812
# j / n_batches: 290 / 590 cost: 3.5734754
# j / n_batches: 300 / 590 cost: 3.6219127
# j / n_batches: 310 / 590 cost: 3.6141043
# j / n_batches: 320 / 590 cost: 3.5807805
# j / n_batches: 330 / 590 cost: 3.600699
# j / n_batches: 340 / 590 cost: 3.5650594
# j / n_batches: 350 / 590 cost: 3.6082475
# j / n_batches: 360 / 590 cost: 3.6847522
# j / n_batches: 370 / 590 cost: 3.603722
# j / n_batches: 380 / 590 cost: 3.6399443
# j / n_batches: 390 / 590 cost: 3.590555
# j / n_batches: 400 / 590 cost: 3.6741288
# j / n_batches: 410 / 590 cost: 3.5447276
# j / n_batches: 420 / 590 cost: 3.5728307
# j / n_batches: 430 / 590 cost: 3.6684394
# j / n_batches: 440 / 590 cost: 3.5583282
# j / n_batches: 450 / 590 cost: 3.6058748
# j / n_batches: 460 / 590 cost: 3.6311238
# j / n_batches: 470 / 590 cost: 3.5749176
# j / n_batches: 480 / 590 cost: 3.6668613
# j / n_batches: 490 / 590 cost: 3.6341107
# j / n_batches: 500 / 590 cost: 3.5659397
# j / n_batches: 510 / 590 cost: 3.6132252
# j / n_batches: 520 / 590 cost: 3.4972131
# j / n_batches: 530 / 590 cost: 3.575283
# j / n_batches: 540 / 590 cost: 3.5541828
# j / n_batches: 550 / 590 cost: 3.622203
# j / n_batches: 560 / 590 cost: 3.5640006
# j / n_batches: 570 / 590 cost: 3.5547733
# j / n_batches: 580 / 590 cost: 3.5358973
# Training rbm: 2
# epoch: 0
# j / n_batches: 0 / 590 cost: 0.7392605
# j / n_batches: 10 / 590 cost: 0.25968626
# j / n_batches: 20 / 590 cost: 0.257516
# j / n_batches: 30 / 590 cost: 0.27664828
# j / n_batches: 40 / 590 cost: 0.29213786
# j / n_batches: 50 / 590 cost: 0.30787444
# j / n_batches: 60 / 590 cost: 0.31252843
# j / n_batches: 70 / 590 cost: 0.32276714
# j / n_batches: 80 / 590 cost: 0.33073083
# j / n_batches: 90 / 590 cost: 0.32177708
# j / n_batches: 100 / 590 cost: 0.3325726
# j / n_batches: 110 / 590 cost: 0.33823165
# j / n_batches: 120 / 590 cost: 0.33545324
# j / n_batches: 130 / 590 cost: 0.3330618
# j / n_batches: 140 / 590 cost: 0.33659813
# j / n_batches: 150 / 590 cost: 0.34496948
# j / n_batches: 160 / 590 cost: 0.33509934
# j / n_batches: 170 / 590 cost: 0.35163754
# j / n_batches: 180 / 590 cost: 0.35536298
# j / n_batches: 190 / 590 cost: 0.34210446
# j / n_batches: 200 / 590 cost: 0.34833446
# j / n_batches: 210 / 590 cost: 0.36453256
# j / n_batches: 220 / 590 cost: 0.3536835
# j / n_batches: 230 / 590 cost: 0.37406275
# j / n_batches: 240 / 590 cost: 0.3600327
# j / n_batches: 250 / 590 cost: 0.36903945
# j / n_batches: 260 / 590 cost: 0.36895934
# j / n_batches: 270 / 590 cost: 0.37784192
# j / n_batches: 280 / 590 cost: 0.3874467
# j / n_batches: 290 / 590 cost: 0.38083038
# j / n_batches: 300 / 590 cost: 0.3887115
# j / n_batches: 310 / 590 cost: 0.39199683
# j / n_batches: 320 / 590 cost: 0.39254984
# j / n_batches: 330 / 590 cost: 0.39474374
# j / n_batches: 340 / 590 cost: 0.39077976
# j / n_batches: 350 / 590 cost: 0.40206766
# j / n_batches: 360 / 590 cost: 0.4139738
# j / n_batches: 370 / 590 cost: 0.3976406
# j / n_batches: 380 / 590 cost: 0.4068436
# j / n_batches: 390 / 590 cost: 0.40531865
# j / n_batches: 400 / 590 cost: 0.41390166
# j / n_batches: 410 / 590 cost: 0.41986248
# j / n_batches: 420 / 590 cost: 0.40705925
# j / n_batches: 430 / 590 cost: 0.40877062
# j / n_batches: 440 / 590 cost: 0.41535157
# j / n_batches: 450 / 590 cost: 0.42512113
# j / n_batches: 460 / 590 cost: 0.42189422
# j / n_batches: 470 / 590 cost: 0.4282182
# j / n_batches: 480 / 590 cost: 0.41288605
# j / n_batches: 490 / 590 cost: 0.43736967
# j / n_batches: 500 / 590 cost: 0.42530656
# j / n_batches: 510 / 590 cost: 0.42763665
# j / n_batches: 520 / 590 cost: 0.4298011
# j / n_batches: 530 / 590 cost: 0.4245346
# j / n_batches: 540 / 590 cost: 0.45032433
# j / n_batches: 550 / 590 cost: 0.43458092
# j / n_batches: 560 / 590 cost: 0.43601942
# j / n_batches: 570 / 590 cost: 0.42225963
# j / n_batches: 580 / 590 cost: 0.44402713
# Supervised Training..
# Epoch: 0
# j / n_batches: 0 / 590 Cost: 5.753825 error: 0.841
# j / n_batches: 10 / 590 Cost: 0.7056815 error: 0.186
# j / n_batches: 20 / 590 Cost: 0.504145 error: 0.149
# j / n_batches: 30 / 590 Cost: 0.40350258 error: 0.096
# j / n_batches: 40 / 590 Cost: 0.33400086 error: 0.095
# j / n_batches: 50 / 590 Cost: 0.2554072 error: 0.069
# j / n_batches: 60 / 590 Cost: 0.27107733 error: 0.081
# j / n_batches: 70 / 590 Cost: 0.2622597 error: 0.078
# j / n_batches: 80 / 590 Cost: 0.21282932 error: 0.071
# j / n_batches: 90 / 590 Cost: 0.20655656 error: 0.065
# j / n_batches: 100 / 590 Cost: 0.23294917 error: 0.069
# j / n_batches: 110 / 590 Cost: 0.23331232 error: 0.065
# j / n_batches: 120 / 590 Cost: 0.27496916 error: 0.065
# j / n_batches: 130 / 590 Cost: 0.17703187 error: 0.05
# j / n_batches: 140 / 590 Cost: 0.2455325 error: 0.068
# j / n_batches: 150 / 590 Cost: 0.21600522 error: 0.054
# j / n_batches: 160 / 590 Cost: 0.2727881 error: 0.089
# j / n_batches: 170 / 590 Cost: 0.19577836 error: 0.064
# j / n_batches: 180 / 590 Cost: 0.18039288 error: 0.046
# j / n_batches: 190 / 590 Cost: 0.20280518 error: 0.062
# j / n_batches: 200 / 590 Cost: 0.17009184 error: 0.052
# j / n_batches: 210 / 590 Cost: 0.18835633 error: 0.049
# j / n_batches: 220 / 590 Cost: 0.11946399 error: 0.033
# j / n_batches: 230 / 590 Cost: 0.14355886 error: 0.044
# j / n_batches: 240 / 590 Cost: 0.13648537 error: 0.043
# j / n_batches: 250 / 590 Cost: 0.17222796 error: 0.06
# j / n_batches: 260 / 590 Cost: 0.14978728 error: 0.042
# j / n_batches: 270 / 590 Cost: 0.15701328 error: 0.055
# j / n_batches: 280 / 590 Cost: 0.13729209 error: 0.037
# j / n_batches: 290 / 590 Cost: 0.17433132 error: 0.052
# j / n_batches: 300 / 590 Cost: 0.17606524 error: 0.043
# j / n_batches: 310 / 590 Cost: 0.16040479 error: 0.047
# j / n_batches: 320 / 590 Cost: 0.15872411 error: 0.047
# j / n_batches: 330 / 590 Cost: 0.13916576 error: 0.048
# j / n_batches: 340 / 590 Cost: 0.15450744 error: 0.048
# j / n_batches: 350 / 590 Cost: 0.1262082 error: 0.038
# j / n_batches: 360 / 590 Cost: 0.12730536 error: 0.043
# j / n_batches: 370 / 590 Cost: 0.13111815 error: 0.043
# j / n_batches: 380 / 590 Cost: 0.10801296 error: 0.032
# j / n_batches: 390 / 590 Cost: 0.14115103 error: 0.042
# j / n_batches: 400 / 590 Cost: 0.12570278 error: 0.038
# j / n_batches: 410 / 590 Cost: 0.16417849 error: 0.048
# j / n_batches: 420 / 590 Cost: 0.13819598 error: 0.036
# j / n_batches: 430 / 590 Cost: 0.121500075 error: 0.043
# j / n_batches: 440 / 590 Cost: 0.1349207 error: 0.041
# j / n_batches: 450 / 590 Cost: 0.12617294 error: 0.043
# j / n_batches: 460 / 590 Cost: 0.17856427 error: 0.06
# j / n_batches: 470 / 590 Cost: 0.1477786 error: 0.047
# j / n_batches: 480 / 590 Cost: 0.1555141 error: 0.048
# j / n_batches: 490 / 590 Cost: 0.1728459 error: 0.053
# j / n_batches: 500 / 590 Cost: 0.12197572 error: 0.036
# j / n_batches: 510 / 590 Cost: 0.14297296 error: 0.04
# j / n_batches: 520 / 590 Cost: 0.13071655 error: 0.038
# j / n_batches: 530 / 590 Cost: 0.14646918 error: 0.052
# j / n_batches: 540 / 590 Cost: 0.14534794 error: 0.044
# j / n_batches: 550 / 590 Cost: 0.15208362 error: 0.046
# j / n_batches: 560 / 590 Cost: 0.13387965 error: 0.039
# j / n_batches: 570 / 590 Cost: 0.13812481 error: 0.041
# j / n_batches: 580 / 590 Cost: 0.107045256 error: 0.031
# Epoch: 1
# j / n_batches: 0 / 590 Cost: 0.12483078 error: 0.04
# j / n_batches: 10 / 590 Cost: 0.12382573 error: 0.035
# j / n_batches: 20 / 590 Cost: 0.122485414 error: 0.028
# j / n_batches: 30 / 590 Cost: 0.13969165 error: 0.038
# j / n_batches: 40 / 590 Cost: 0.111007586 error: 0.035
# j / n_batches: 50 / 590 Cost: 0.1012077 error: 0.028
# j / n_batches: 60 / 590 Cost: 0.10023398 error: 0.024
# j / n_batches: 70 / 590 Cost: 0.11740482 error: 0.034
# j / n_batches: 80 / 590 Cost: 0.11393518 error: 0.029
# j / n_batches: 90 / 590 Cost: 0.13664903 error: 0.038
# j / n_batches: 100 / 590 Cost: 0.10726609 error: 0.031
# j / n_batches: 110 / 590 Cost: 0.09438521 error: 0.031
# j / n_batches: 120 / 590 Cost: 0.122914866 error: 0.039
# j / n_batches: 130 / 590 Cost: 0.11653888 error: 0.036
# j / n_batches: 140 / 590 Cost: 0.12976074 error: 0.037
# j / n_batches: 150 / 590 Cost: 0.10404317 error: 0.026
# j / n_batches: 160 / 590 Cost: 0.11580507 error: 0.037
# j / n_batches: 170 / 590 Cost: 0.09795624 error: 0.034
# j / n_batches: 180 / 590 Cost: 0.116923295 error: 0.037
# j / n_batches: 190 / 590 Cost: 0.11254022 error: 0.034
# j / n_batches: 200 / 590 Cost: 0.11779247 error: 0.039
# j / n_batches: 210 / 590 Cost: 0.12803176 error: 0.037
# j / n_batches: 220 / 590 Cost: 0.13063525 error: 0.04
# j / n_batches: 230 / 590 Cost: 0.1165672 error: 0.04
# j / n_batches: 240 / 590 Cost: 0.107712954 error: 0.031
# j / n_batches: 250 / 590 Cost: 0.10509214 error: 0.027
# j / n_batches: 260 / 590 Cost: 0.10135265 error: 0.028
# j / n_batches: 270 / 590 Cost: 0.11179748 error: 0.03
# j / n_batches: 280 / 590 Cost: 0.1187261 error: 0.038
# j / n_batches: 290 / 590 Cost: 0.12969129 error: 0.037
# j / n_batches: 300 / 590 Cost: 0.12923318 error: 0.034
# j / n_batches: 310 / 590 Cost: 0.12184028 error: 0.034
# j / n_batches: 320 / 590 Cost: 0.13715982 error: 0.033
# j / n_batches: 330 / 590 Cost: 0.15141697 error: 0.036
# j / n_batches: 340 / 590 Cost: 0.15801236 error: 0.041
# j / n_batches: 350 / 590 Cost: 0.13478091 error: 0.043
# j / n_batches: 360 / 590 Cost: 0.11777482 error: 0.03
# j / n_batches: 370 / 590 Cost: 0.11341299 error: 0.035
# j / n_batches: 380 / 590 Cost: 0.12153906 error: 0.026
# j / n_batches: 390 / 590 Cost: 0.110356495 error: 0.03
# j / n_batches: 400 / 590 Cost: 0.14477627 error: 0.036
# j / n_batches: 410 / 590 Cost: 0.13494156 error: 0.033
# j / n_batches: 420 / 590 Cost: 0.16232449 error: 0.045
# j / n_batches: 430 / 590 Cost: 0.13561442 error: 0.039
# j / n_batches: 440 / 590 Cost: 0.14315557 error: 0.039
# j / n_batches: 450 / 590 Cost: 0.20362528 error: 0.058
# j / n_batches: 460 / 590 Cost: 0.11701894 error: 0.031
# j / n_batches: 470 / 590 Cost: 0.10818292 error: 0.021
# j / n_batches: 480 / 590 Cost: 0.12480914 error: 0.034
# j / n_batches: 490 / 590 Cost: 0.11517267 error: 0.034
# j / n_batches: 500 / 590 Cost: 0.13542661 error: 0.037
# j / n_batches: 510 / 590 Cost: 0.11180599 error: 0.032
# j / n_batches: 520 / 590 Cost: 0.13484532 error: 0.037
# j / n_batches: 530 / 590 Cost: 0.10191606 error: 0.027
# j / n_batches: 540 / 590 Cost: 0.13684604 error: 0.033
# j / n_batches: 550 / 590 Cost: 0.104620196 error: 0.027
# j / n_batches: 560 / 590 Cost: 0.11271107 error: 0.032
# j / n_batches: 570 / 590 Cost: 0.11943019 error: 0.033
# j / n_batches: 580 / 590 Cost: 0.09859531 error: 0.029
# Epoch: 2
# j / n_batches: 0 / 590 Cost: 0.10470457 error: 0.022
# j / n_batches: 10 / 590 Cost: 0.1026608 error: 0.023
# j / n_batches: 20 / 590 Cost: 0.13173093 error: 0.026
# j / n_batches: 30 / 590 Cost: 0.12108634 error: 0.027
# j / n_batches: 40 / 590 Cost: 0.19129154 error: 0.048
# j / n_batches: 50 / 590 Cost: 0.1472973 error: 0.037
# j / n_batches: 60 / 590 Cost: 0.13947271 error: 0.038
# j / n_batches: 70 / 590 Cost: 0.1544433 error: 0.04
# j / n_batches: 80 / 590 Cost: 0.111378916 error: 0.035
# j / n_batches: 90 / 590 Cost: 0.12271041 error: 0.031
# j / n_batches: 100 / 590 Cost: 0.09454797 error: 0.03
# j / n_batches: 110 / 590 Cost: 0.11606352 error: 0.037
# j / n_batches: 120 / 590 Cost: 0.108764105 error: 0.032
# j / n_batches: 130 / 590 Cost: 0.12108362 error: 0.034
# j / n_batches: 140 / 590 Cost: 0.095548734 error: 0.024
# j / n_batches: 150 / 590 Cost: 0.13252509 error: 0.031
# j / n_batches: 160 / 590 Cost: 0.13257548 error: 0.029
# j / n_batches: 170 / 590 Cost: 0.13665958 error: 0.03
# j / n_batches: 180 / 590 Cost: 0.1661348 error: 0.039
# j / n_batches: 190 / 590 Cost: 0.118752226 error: 0.027
# j / n_batches: 200 / 590 Cost: 0.11636107 error: 0.028
# j / n_batches: 210 / 590 Cost: 0.10567675 error: 0.026
# j / n_batches: 220 / 590 Cost: 0.10159298 error: 0.025
# j / n_batches: 230 / 590 Cost: 0.14195682 error: 0.032
# j / n_batches: 240 / 590 Cost: 0.10767552 error: 0.021
# j / n_batches: 250 / 590 Cost: 0.11849302 error: 0.029
# j / n_batches: 260 / 590 Cost: 0.114535995 error: 0.033
# j / n_batches: 270 / 590 Cost: 0.10661611 error: 0.032
# j / n_batches: 280 / 590 Cost: 0.1298248 error: 0.039
# j / n_batches: 290 / 590 Cost: 0.11642929 error: 0.028
# j / n_batches: 300 / 590 Cost: 0.15576206 error: 0.039
# j / n_batches: 310 / 590 Cost: 0.13873823 error: 0.04
# j / n_batches: 320 / 590 Cost: 0.09991917 error: 0.028
# j / n_batches: 330 / 590 Cost: 0.098221734 error: 0.022
# j / n_batches: 340 / 590 Cost: 0.14989746 error: 0.045
# j / n_batches: 350 / 590 Cost: 0.13682507 error: 0.038
# j / n_batches: 360 / 590 Cost: 0.11960345 error: 0.041
# j / n_batches: 370 / 590 Cost: 0.13917848 error: 0.034
# j / n_batches: 380 / 590 Cost: 0.14082225 error: 0.034
# j / n_batches: 390 / 590 Cost: 0.11360016 error: 0.025
# j / n_batches: 400 / 590 Cost: 0.12369026 error: 0.034
# j / n_batches: 410 / 590 Cost: 0.10531119 error: 0.028
# j / n_batches: 420 / 590 Cost: 0.1331026 error: 0.039
# j / n_batches: 430 / 590 Cost: 0.10919336 error: 0.027
# j / n_batches: 440 / 590 Cost: 0.11724477 error: 0.029
# j / n_batches: 450 / 590 Cost: 0.12575132 error: 0.03
# j / n_batches: 460 / 590 Cost: 0.14552294 error: 0.044
# j / n_batches: 470 / 590 Cost: 0.13686794 error: 0.036
# j / n_batches: 480 / 590 Cost: 0.14098619 error: 0.041
# j / n_batches: 490 / 590 Cost: 0.11785485 error: 0.038
# j / n_batches: 500 / 590 Cost: 0.10094655 error: 0.024
# j / n_batches: 510 / 590 Cost: 0.103253216 error: 0.026
# j / n_batches: 520 / 590 Cost: 0.12038957 error: 0.036
# j / n_batches: 530 / 590 Cost: 0.10839662 error: 0.03
# j / n_batches: 540 / 590 Cost: 0.12887931 error: 0.041
# j / n_batches: 550 / 590 Cost: 0.0816486 error: 0.021
# j / n_batches: 560 / 590 Cost: 0.08664052 error: 0.023
# j / n_batches: 570 / 590 Cost: 0.11648391 error: 0.031
# j / n_batches: 580 / 590 Cost: 0.11339058 error: 0.029
# Epoch: 3
# j / n_batches: 0 / 590 Cost: 0.10059508 error: 0.031
# j / n_batches: 10 / 590 Cost: 0.105626404 error: 0.032
# j / n_batches: 20 / 590 Cost: 0.108629495 error: 0.029
# j / n_batches: 30 / 590 Cost: 0.11038432 error: 0.028
# j / n_batches: 40 / 590 Cost: 0.09585398 error: 0.031
# j / n_batches: 50 / 590 Cost: 0.110535905 error: 0.032
# j / n_batches: 60 / 590 Cost: 0.1282425 error: 0.037
# j / n_batches: 70 / 590 Cost: 0.07406888 error: 0.02
# j / n_batches: 80 / 590 Cost: 0.07563191 error: 0.023
# j / n_batches: 90 / 590 Cost: 0.06681865 error: 0.024
# j / n_batches: 100 / 590 Cost: 0.089950636 error: 0.025
# j / n_batches: 110 / 590 Cost: 0.07871134 error: 0.023
# j / n_batches: 120 / 590 Cost: 0.08323312 error: 0.023
# j / n_batches: 130 / 590 Cost: 0.09434411 error: 0.028
# j / n_batches: 140 / 590 Cost: 0.112742074 error: 0.032
# j / n_batches: 150 / 590 Cost: 0.10013213 error: 0.024
# j / n_batches: 160 / 590 Cost: 0.089544 error: 0.026
# j / n_batches: 170 / 590 Cost: 0.094209835 error: 0.03
# j / n_batches: 180 / 590 Cost: 0.090790026 error: 0.029
# j / n_batches: 190 / 590 Cost: 0.12118161 error: 0.037
# j / n_batches: 200 / 590 Cost: 0.13239239 error: 0.033
# j / n_batches: 210 / 590 Cost: 0.14368176 error: 0.039
# j / n_batches: 220 / 590 Cost: 0.104771316 error: 0.026
# j / n_batches: 230 / 590 Cost: 0.13909207 error: 0.031
# j / n_batches: 240 / 590 Cost: 0.11277172 error: 0.029
# j / n_batches: 250 / 590 Cost: 0.10469206 error: 0.028
# j / n_batches: 260 / 590 Cost: 0.0889415 error: 0.03
# j / n_batches: 270 / 590 Cost: 0.10475644 error: 0.025
# j / n_batches: 280 / 590 Cost: 0.10546245 error: 0.028
# j / n_batches: 290 / 590 Cost: 0.09786224 error: 0.031
# j / n_batches: 300 / 590 Cost: 0.110952206 error: 0.026
# j / n_batches: 310 / 590 Cost: 0.11587114 error: 0.031
# j / n_batches: 320 / 590 Cost: 0.10499089 error: 0.024
# j / n_batches: 330 / 590 Cost: 0.09487832 error: 0.029
# j / n_batches: 340 / 590 Cost: 0.10692443 error: 0.027
# j / n_batches: 350 / 590 Cost: 0.10089616 error: 0.024
# j / n_batches: 360 / 590 Cost: 0.09247503 error: 0.024
# j / n_batches: 370 / 590 Cost: 0.12217799 error: 0.032
# j / n_batches: 380 / 590 Cost: 0.10199969 error: 0.029
# j / n_batches: 390 / 590 Cost: 0.114857346 error: 0.03
# j / n_batches: 400 / 590 Cost: 0.123060174 error: 0.038
# j / n_batches: 410 / 590 Cost: 0.113615125 error: 0.026
# j / n_batches: 420 / 590 Cost: 0.14460012 error: 0.034
# j / n_batches: 430 / 590 Cost: 0.19236103 error: 0.048
# j / n_batches: 440 / 590 Cost: 0.17965509 error: 0.043
# j / n_batches: 450 / 590 Cost: 0.13510083 error: 0.039
# j / n_batches: 460 / 590 Cost: 0.112026446 error: 0.027
# j / n_batches: 470 / 590 Cost: 0.120948836 error: 0.036
# j / n_batches: 480 / 590 Cost: 0.13303329 error: 0.031
# j / n_batches: 490 / 590 Cost: 0.106798895 error: 0.03
# j / n_batches: 500 / 590 Cost: 0.09276382 error: 0.023
# j / n_batches: 510 / 590 Cost: 0.16572009 error: 0.036
# j / n_batches: 520 / 590 Cost: 0.11671359 error: 0.034
# j / n_batches: 530 / 590 Cost: 0.11777147 error: 0.03
# j / n_batches: 540 / 590 Cost: 0.109752834 error: 0.027
# j / n_batches: 550 / 590 Cost: 0.12657942 error: 0.036
# j / n_batches: 560 / 590 Cost: 0.1038154 error: 0.031
# j / n_batches: 570 / 590 Cost: 0.09704043 error: 0.022
# j / n_batches: 580 / 590 Cost: 0.12280958 error: 0.032
# Epoch: 4
# j / n_batches: 0 / 590 Cost: 0.11365723 error: 0.028
# j / n_batches: 10 / 590 Cost: 0.1108232 error: 0.025
# j / n_batches: 20 / 590 Cost: 0.111315764 error: 0.03
# j / n_batches: 30 / 590 Cost: 0.1107974 error: 0.026
# j / n_batches: 40 / 590 Cost: 0.10096669 error: 0.03
# j / n_batches: 50 / 590 Cost: 0.12260945 error: 0.03
# j / n_batches: 60 / 590 Cost: 0.15465079 error: 0.033
# j / n_batches: 70 / 590 Cost: 0.123823844 error: 0.031
# j / n_batches: 80 / 590 Cost: 0.13203259 error: 0.037
# j / n_batches: 90 / 590 Cost: 0.15814826 error: 0.038
# j / n_batches: 100 / 590 Cost: 0.14415751 error: 0.041
# j / n_batches: 110 / 590 Cost: 0.18267988 error: 0.04
# j / n_batches: 120 / 590 Cost: 0.12361822 error: 0.033
# j / n_batches: 130 / 590 Cost: 0.111210816 error: 0.034
# j / n_batches: 140 / 590 Cost: 0.11205091 error: 0.033
# j / n_batches: 150 / 590 Cost: 0.1097555 error: 0.032
# j / n_batches: 160 / 590 Cost: 0.10837989 error: 0.028
# j / n_batches: 170 / 590 Cost: 0.11512372 error: 0.031
# j / n_batches: 180 / 590 Cost: 0.10395187 error: 0.028
# j / n_batches: 190 / 590 Cost: 0.08605748 error: 0.022
# j / n_batches: 200 / 590 Cost: 0.1169842 error: 0.034
# j / n_batches: 210 / 590 Cost: 0.12036174 error: 0.03
# j / n_batches: 220 / 590 Cost: 0.18930088 error: 0.052
# j / n_batches: 230 / 590 Cost: 0.10626065 error: 0.025
# j / n_batches: 240 / 590 Cost: 0.10106042 error: 0.022
# j / n_batches: 250 / 590 Cost: 0.11011214 error: 0.029
# j / n_batches: 260 / 590 Cost: 0.10135369 error: 0.025
# j / n_batches: 270 / 590 Cost: 0.13109198 error: 0.03
# j / n_batches: 280 / 590 Cost: 0.11917284 error: 0.03
# j / n_batches: 290 / 590 Cost: 0.14670612 error: 0.043
# j / n_batches: 300 / 590 Cost: 0.12887082 error: 0.033
# j / n_batches: 310 / 590 Cost: 0.14857788 error: 0.04
# j / n_batches: 320 / 590 Cost: 0.11519897 error: 0.03
# j / n_batches: 330 / 590 Cost: 0.119514905 error: 0.033
# j / n_batches: 340 / 590 Cost: 0.090859495 error: 0.024
# j / n_batches: 350 / 590 Cost: 0.1262684 error: 0.033
# j / n_batches: 360 / 590 Cost: 0.15108986 error: 0.039
# j / n_batches: 370 / 590 Cost: 0.09969294 error: 0.025
# j / n_batches: 380 / 590 Cost: 0.12514028 error: 0.025
# j / n_batches: 390 / 590 Cost: 0.115864776 error: 0.024
# j / n_batches: 400 / 590 Cost: 0.14195907 error: 0.037
# j / n_batches: 410 / 590 Cost: 0.14236394 error: 0.032
# j / n_batches: 420 / 590 Cost: 0.13546363 error: 0.032
# j / n_batches: 430 / 590 Cost: 0.14527732 error: 0.041
# j / n_batches: 440 / 590 Cost: 0.14749868 error: 0.041
# j / n_batches: 450 / 590 Cost: 0.15678155 error: 0.04
# j / n_batches: 460 / 590 Cost: 0.15878037 error: 0.033
# j / n_batches: 470 / 590 Cost: 0.13308945 error: 0.033
# j / n_batches: 480 / 590 Cost: 0.15743658 error: 0.042
# j / n_batches: 490 / 590 Cost: 0.13118778 error: 0.033
# j / n_batches: 500 / 590 Cost: 0.14590947 error: 0.034
# j / n_batches: 510 / 590 Cost: 0.1088555 error: 0.031
# j / n_batches: 520 / 590 Cost: 0.15543108 error: 0.033
# j / n_batches: 530 / 590 Cost: 0.1095067 error: 0.031
# j / n_batches: 540 / 590 Cost: 0.1398261 error: 0.028
# j / n_batches: 550 / 590 Cost: 0.11817405 error: 0.029
# j / n_batches: 560 / 590 Cost: 0.12851499 error: 0.038
# j / n_batches: 570 / 590 Cost: 0.11027901 error: 0.033
# j / n_batches: 580 / 590 Cost: 0.079804584 error: 0.022
# Epoch: 5
# j / n_batches: 0 / 590 Cost: 0.06821369 error: 0.02
# j / n_batches: 10 / 590 Cost: 0.09653392 error: 0.029
# j / n_batches: 20 / 590 Cost: 0.113029584 error: 0.026
# j / n_batches: 30 / 590 Cost: 0.11520454 error: 0.033
# j / n_batches: 40 / 590 Cost: 0.12912145 error: 0.032
# j / n_batches: 50 / 590 Cost: 0.13033515 error: 0.029
# j / n_batches: 60 / 590 Cost: 0.11324999 error: 0.035
# j / n_batches: 70 / 590 Cost: 0.12422107 error: 0.029
# j / n_batches: 80 / 590 Cost: 0.10603008 error: 0.024
# j / n_batches: 90 / 590 Cost: 0.17090647 error: 0.048
# j / n_batches: 100 / 590 Cost: 0.11014235 error: 0.032
# j / n_batches: 110 / 590 Cost: 0.12743013 error: 0.034
# j / n_batches: 120 / 590 Cost: 0.109991044 error: 0.026
# j / n_batches: 130 / 590 Cost: 0.11043782 error: 0.026
# j / n_batches: 140 / 590 Cost: 0.10530891 error: 0.028
# j / n_batches: 150 / 590 Cost: 0.13362105 error: 0.032
# j / n_batches: 160 / 590 Cost: 0.15487 error: 0.035
# j / n_batches: 170 / 590 Cost: 0.1446251 error: 0.029
# j / n_batches: 180 / 590 Cost: 0.12001157 error: 0.03
# j / n_batches: 190 / 590 Cost: 0.13333386 error: 0.029
# j / n_batches: 200 / 590 Cost: 0.1357482 error: 0.03
# j / n_batches: 210 / 590 Cost: 0.096235245 error: 0.024
# j / n_batches: 220 / 590 Cost: 0.08977366 error: 0.022
# j / n_batches: 230 / 590 Cost: 0.09565601 error: 0.021
# j / n_batches: 240 / 590 Cost: 0.107418366 error: 0.032
# j / n_batches: 250 / 590 Cost: 0.119605996 error: 0.033
# j / n_batches: 260 / 590 Cost: 0.12058529 error: 0.033
# j / n_batches: 270 / 590 Cost: 0.10001775 error: 0.03
# j / n_batches: 280 / 590 Cost: 0.099847816 error: 0.026
# j / n_batches: 290 / 590 Cost: 0.105356626 error: 0.031
# j / n_batches: 300 / 590 Cost: 0.123395406 error: 0.03
# j / n_batches: 310 / 590 Cost: 0.10619763 error: 0.033
# j / n_batches: 320 / 590 Cost: 0.11916315 error: 0.034
# j / n_batches: 330 / 590 Cost: 0.12864417 error: 0.032
# j / n_batches: 340 / 590 Cost: 0.10866249 error: 0.029
# j / n_batches: 350 / 590 Cost: 0.12095387 error: 0.033
# j / n_batches: 360 / 590 Cost: 0.13901784 error: 0.04
# j / n_batches: 370 / 590 Cost: 0.11483937 error: 0.033
# j / n_batches: 380 / 590 Cost: 0.09915873 error: 0.021
# j / n_batches: 390 / 590 Cost: 0.097420976 error: 0.025
# j / n_batches: 400 / 590 Cost: 0.10906307 error: 0.028
# j / n_batches: 410 / 590 Cost: 0.12643509 error: 0.027
# j / n_batches: 420 / 590 Cost: 0.1146744 error: 0.033
# j / n_batches: 430 / 590 Cost: 0.12259533 error: 0.031
# j / n_batches: 440 / 590 Cost: 0.12099039 error: 0.031
# j / n_batches: 450 / 590 Cost: 0.106022455 error: 0.029
# j / n_batches: 460 / 590 Cost: 0.101445325 error: 0.024
# j / n_batches: 470 / 590 Cost: 0.11465215 error: 0.03
# j / n_batches: 480 / 590 Cost: 0.10077389 error: 0.022
# j / n_batches: 490 / 590 Cost: 0.12535785 error: 0.036
# j / n_batches: 500 / 590 Cost: 0.09728389 error: 0.028
# j / n_batches: 510 / 590 Cost: 0.09543568 error: 0.027
# j / n_batches: 520 / 590 Cost: 0.084621064 error: 0.025
# j / n_batches: 530 / 590 Cost: 0.13892475 error: 0.04
# j / n_batches: 540 / 590 Cost: 0.14346007 error: 0.033
# j / n_batches: 550 / 590 Cost: 0.12245958 error: 0.029
# j / n_batches: 560 / 590 Cost: 0.13934836 error: 0.037
# j / n_batches: 570 / 590 Cost: 0.12461033 error: 0.031
# j / n_batches: 580 / 590 Cost: 0.15168266 error: 0.034
# Epoch: 6
# j / n_batches: 0 / 590 Cost: 0.1526236 error: 0.04
# j / n_batches: 10 / 590 Cost: 0.13190207 error: 0.039
# j / n_batches: 20 / 590 Cost: 0.15030055 error: 0.042
# j / n_batches: 30 / 590 Cost: 0.10541909 error: 0.031
# j / n_batches: 40 / 590 Cost: 0.09578433 error: 0.025
# j / n_batches: 50 / 590 Cost: 0.09314569 error: 0.023
# j / n_batches: 60 / 590 Cost: 0.12599 error: 0.031
# j / n_batches: 70 / 590 Cost: 0.1462063 error: 0.038
# j / n_batches: 80 / 590 Cost: 0.13217276 error: 0.034
# j / n_batches: 90 / 590 Cost: 0.13363315 error: 0.044
# j / n_batches: 100 / 590 Cost: 0.14585342 error: 0.038
# j / n_batches: 110 / 590 Cost: 0.1188903 error: 0.036
# j / n_batches: 120 / 590 Cost: 0.14121427 error: 0.041
# j / n_batches: 130 / 590 Cost: 0.11527626 error: 0.028
# j / n_batches: 140 / 590 Cost: 0.10495877 error: 0.024
# j / n_batches: 150 / 590 Cost: 0.10925592 error: 0.026
# j / n_batches: 160 / 590 Cost: 0.078462854 error: 0.02
# j / n_batches: 170 / 590 Cost: 0.14266081 error: 0.047
# j / n_batches: 180 / 590 Cost: 0.15650317 error: 0.041
# j / n_batches: 190 / 590 Cost: 0.13366178 error: 0.033
# j / n_batches: 200 / 590 Cost: 0.13012299 error: 0.042
# j / n_batches: 210 / 590 Cost: 0.12107383 error: 0.031
# j / n_batches: 220 / 590 Cost: 0.1095128 error: 0.024
# j / n_batches: 230 / 590 Cost: 0.10321064 error: 0.024
# j / n_batches: 240 / 590 Cost: 0.13917254 error: 0.035
# j / n_batches: 250 / 590 Cost: 0.14620334 error: 0.035
# j / n_batches: 260 / 590 Cost: 0.12860736 error: 0.033
# j / n_batches: 270 / 590 Cost: 0.17743695 error: 0.039
# j / n_batches: 280 / 590 Cost: 0.14913866 error: 0.036
# j / n_batches: 290 / 590 Cost: 0.17039135 error: 0.039
# j / n_batches: 300 / 590 Cost: 0.14208871 error: 0.035
# j / n_batches: 310 / 590 Cost: 0.13839033 error: 0.035
# j / n_batches: 320 / 590 Cost: 0.117617294 error: 0.029
# j / n_batches: 330 / 590 Cost: 0.13594322 error: 0.035
# j / n_batches: 340 / 590 Cost: 0.109950036 error: 0.033
# j / n_batches: 350 / 590 Cost: 0.10610538 error: 0.033
# j / n_batches: 360 / 590 Cost: 0.08124961 error: 0.025
# j / n_batches: 370 / 590 Cost: 0.12464951 error: 0.034
# j / n_batches: 380 / 590 Cost: 0.12196536 error: 0.027
# j / n_batches: 390 / 590 Cost: 0.12235695 error: 0.025
# j / n_batches: 400 / 590 Cost: 0.094993934 error: 0.022
# j / n_batches: 410 / 590 Cost: 0.10985633 error: 0.032
# j / n_batches: 420 / 590 Cost: 0.11169516 error: 0.031
# j / n_batches: 430 / 590 Cost: 0.09532387 error: 0.023
# j / n_batches: 440 / 590 Cost: 0.12048139 error: 0.035
# j / n_batches: 450 / 590 Cost: 0.1372948 error: 0.036
# j / n_batches: 460 / 590 Cost: 0.11155783 error: 0.033
# j / n_batches: 470 / 590 Cost: 0.11516564 error: 0.031
# j / n_batches: 480 / 590 Cost: 0.12033512 error: 0.032
# j / n_batches: 490 / 590 Cost: 0.12010481 error: 0.03
# j / n_batches: 500 / 590 Cost: 0.12244751 error: 0.032
# j / n_batches: 510 / 590 Cost: 0.14452791 error: 0.034
# j / n_batches: 520 / 590 Cost: 0.10254588 error: 0.029
# j / n_batches: 530 / 590 Cost: 0.12979224 error: 0.028
# j / n_batches: 540 / 590 Cost: 0.10906644 error: 0.029
# j / n_batches: 550 / 590 Cost: 0.13499545 error: 0.037
# j / n_batches: 560 / 590 Cost: 0.13647898 error: 0.036
# j / n_batches: 570 / 590 Cost: 0.12238802 error: 0.032
# j / n_batches: 580 / 590 Cost: 0.15654047 error: 0.035
# Epoch: 7
# j / n_batches: 0 / 590 Cost: 0.1479844 error: 0.032
# j / n_batches: 10 / 590 Cost: 0.14282925 error: 0.033
# j / n_batches: 20 / 590 Cost: 0.13043915 error: 0.03
# j / n_batches: 30 / 590 Cost: 0.12477826 error: 0.028
# j / n_batches: 40 / 590 Cost: 0.15708402 error: 0.035
# j / n_batches: 50 / 590 Cost: 0.14138004 error: 0.027
# j / n_batches: 60 / 590 Cost: 0.14312221 error: 0.035
# j / n_batches: 70 / 590 Cost: 0.11751718 error: 0.029
# j / n_batches: 80 / 590 Cost: 0.10377317 error: 0.025
# j / n_batches: 90 / 590 Cost: 0.11874623 error: 0.031
# j / n_batches: 100 / 590 Cost: 0.15354969 error: 0.037
# j / n_batches: 110 / 590 Cost: 0.10600656 error: 0.026
# j / n_batches: 120 / 590 Cost: 0.1267905 error: 0.031
# j / n_batches: 130 / 590 Cost: 0.13400906 error: 0.035
# j / n_batches: 140 / 590 Cost: 0.1105894 error: 0.028
# j / n_batches: 150 / 590 Cost: 0.10977969 error: 0.026
# j / n_batches: 160 / 590 Cost: 0.13742147 error: 0.032
# j / n_batches: 170 / 590 Cost: 0.10896249 error: 0.022
# j / n_batches: 180 / 590 Cost: 0.12104873 error: 0.029
# j / n_batches: 190 / 590 Cost: 0.11774843 error: 0.026
# j / n_batches: 200 / 590 Cost: 0.1311055 error: 0.036
# j / n_batches: 210 / 590 Cost: 0.12042674 error: 0.03
# j / n_batches: 220 / 590 Cost: 0.1730627 error: 0.045
# j / n_batches: 230 / 590 Cost: 0.1709021 error: 0.041
# j / n_batches: 240 / 590 Cost: 0.12455233 error: 0.036
# j / n_batches: 250 / 590 Cost: 0.1061787 error: 0.021
# j / n_batches: 260 / 590 Cost: 0.112487234 error: 0.026
# j / n_batches: 270 / 590 Cost: 0.12395515 error: 0.033
# j / n_batches: 280 / 590 Cost: 0.110967025 error: 0.028
# j / n_batches: 290 / 590 Cost: 0.12509759 error: 0.029
# j / n_batches: 300 / 590 Cost: 0.101880014 error: 0.028
# j / n_batches: 310 / 590 Cost: 0.11941072 error: 0.03
# j / n_batches: 320 / 590 Cost: 0.122026406 error: 0.025
# j / n_batches: 330 / 590 Cost: 0.1124293 error: 0.024
# j / n_batches: 340 / 590 Cost: 0.121678635 error: 0.027
# j / n_batches: 350 / 590 Cost: 0.12989025 error: 0.034
# j / n_batches: 360 / 590 Cost: 0.11638605 error: 0.03
# j / n_batches: 370 / 590 Cost: 0.123918064 error: 0.034
# j / n_batches: 380 / 590 Cost: 0.13927072 error: 0.035
# j / n_batches: 390 / 590 Cost: 0.11594241 error: 0.035
# j / n_batches: 400 / 590 Cost: 0.12016707 error: 0.031
# j / n_batches: 410 / 590 Cost: 0.12833078 error: 0.037
# j / n_batches: 420 / 590 Cost: 0.11061575 error: 0.03
# j / n_batches: 430 / 590 Cost: 0.10578361 error: 0.031
# j / n_batches: 440 / 590 Cost: 0.10076214 error: 0.029
# j / n_batches: 450 / 590 Cost: 0.12118775 error: 0.027
# j / n_batches: 460 / 590 Cost: 0.13394052 error: 0.031
# j / n_batches: 470 / 590 Cost: 0.097662285 error: 0.024
# j / n_batches: 480 / 590 Cost: 0.097268954 error: 0.026
# j / n_batches: 490 / 590 Cost: 0.12015918 error: 0.032
# j / n_batches: 500 / 590 Cost: 0.1284943 error: 0.031
# j / n_batches: 510 / 590 Cost: 0.096201934 error: 0.022
# j / n_batches: 520 / 590 Cost: 0.100289 error: 0.028
# j / n_batches: 530 / 590 Cost: 0.08676817 error: 0.029
# j / n_batches: 540 / 590 Cost: 0.082945526 error: 0.024
# j / n_batches: 550 / 590 Cost: 0.08652495 error: 0.026
# j / n_batches: 560 / 590 Cost: 0.08367067 error: 0.027
# j / n_batches: 570 / 590 Cost: 0.10746112 error: 0.035
# j / n_batches: 580 / 590 Cost: 0.10256729 error: 0.032
# Epoch: 8
# j / n_batches: 0 / 590 Cost: 0.10257876 error: 0.03
# j / n_batches: 10 / 590 Cost: 0.122137256 error: 0.033
# j / n_batches: 20 / 590 Cost: 0.103925005 error: 0.034
# j / n_batches: 30 / 590 Cost: 0.08886406 error: 0.023
# j / n_batches: 40 / 590 Cost: 0.11263358 error: 0.028
# j / n_batches: 50 / 590 Cost: 0.1187 error: 0.02
# j / n_batches: 60 / 590 Cost: 0.11446712 error: 0.027
# j / n_batches: 70 / 590 Cost: 0.13341577 error: 0.035
# j / n_batches: 80 / 590 Cost: 0.11220765 error: 0.03
# j / n_batches: 90 / 590 Cost: 0.11866908 error: 0.033
# j / n_batches: 100 / 590 Cost: 0.11976908 error: 0.029
# j / n_batches: 110 / 590 Cost: 0.12979183 error: 0.028
# j / n_batches: 120 / 590 Cost: 0.1261746 error: 0.024
# j / n_batches: 130 / 590 Cost: 0.10553489 error: 0.023
# j / n_batches: 140 / 590 Cost: 0.09663599 error: 0.022
# j / n_batches: 150 / 590 Cost: 0.17107627 error: 0.043
# j / n_batches: 160 / 590 Cost: 0.11801897 error: 0.032
# j / n_batches: 170 / 590 Cost: 0.11684968 error: 0.026
# j / n_batches: 180 / 590 Cost: 0.1549644 error: 0.039
# j / n_batches: 190 / 590 Cost: 0.15208592 error: 0.042
# j / n_batches: 200 / 590 Cost: 0.13505346 error: 0.039
# j / n_batches: 210 / 590 Cost: 0.14318433 error: 0.033
# j / n_batches: 220 / 590 Cost: 0.12000744 error: 0.03
# j / n_batches: 230 / 590 Cost: 0.14694381 error: 0.037
# j / n_batches: 240 / 590 Cost: 0.096606635 error: 0.029
# j / n_batches: 250 / 590 Cost: 0.10379457 error: 0.023
# j / n_batches: 260 / 590 Cost: 0.1295933 error: 0.032
# j / n_batches: 270 / 590 Cost: 0.10094208 error: 0.027
# j / n_batches: 280 / 590 Cost: 0.10185653 error: 0.023
# j / n_batches: 290 / 590 Cost: 0.12201029 error: 0.023
# j / n_batches: 300 / 590 Cost: 0.11914505 error: 0.027
# j / n_batches: 310 / 590 Cost: 0.12832776 error: 0.03
# j / n_batches: 320 / 590 Cost: 0.10918812 error: 0.025
# j / n_batches: 330 / 590 Cost: 0.104108945 error: 0.028
# j / n_batches: 340 / 590 Cost: 0.12455503 error: 0.029
# j / n_batches: 350 / 590 Cost: 0.09893884 error: 0.025
# j / n_batches: 360 / 590 Cost: 0.08982057 error: 0.028
# j / n_batches: 370 / 590 Cost: 0.15677086 error: 0.04
# j / n_batches: 380 / 590 Cost: 0.11841579 error: 0.034
# j / n_batches: 390 / 590 Cost: 0.13075756 error: 0.037
# j / n_batches: 400 / 590 Cost: 0.13112542 error: 0.036
# j / n_batches: 410 / 590 Cost: 0.13283734 error: 0.039
# j / n_batches: 420 / 590 Cost: 0.12061855 error: 0.034
# j / n_batches: 430 / 590 Cost: 0.124114275 error: 0.03
# j / n_batches: 440 / 590 Cost: 0.10762506 error: 0.033
# j / n_batches: 450 / 590 Cost: 0.10299257 error: 0.032
# j / n_batches: 460 / 590 Cost: 0.12141913 error: 0.03
# j / n_batches: 470 / 590 Cost: 0.11592072 error: 0.027
# j / n_batches: 480 / 590 Cost: 0.0960643 error: 0.024
# j / n_batches: 490 / 590 Cost: 0.09143892 error: 0.019
# j / n_batches: 500 / 590 Cost: 0.07766926 error: 0.022
# j / n_batches: 510 / 590 Cost: 0.11836911 error: 0.035
# j / n_batches: 520 / 590 Cost: 0.13431303 error: 0.039
# j / n_batches: 530 / 590 Cost: 0.11755452 error: 0.033
# j / n_batches: 540 / 590 Cost: 0.121849164 error: 0.031
# j / n_batches: 550 / 590 Cost: 0.12636043 error: 0.023
# j / n_batches: 560 / 590 Cost: 0.111132436 error: 0.03
# j / n_batches: 570 / 590 Cost: 0.08545593 error: 0.018
# j / n_batches: 580 / 590 Cost: 0.11029058 error: 0.033
# Epoch: 9
# j / n_batches: 0 / 590 Cost: 0.112243235 error: 0.03
# j / n_batches: 10 / 590 Cost: 0.09779616 error: 0.032
# j / n_batches: 20 / 590 Cost: 0.08877005 error: 0.022
# j / n_batches: 30 / 590 Cost: 0.14004599 error: 0.038
# j / n_batches: 40 / 590 Cost: 0.15288052 error: 0.036
# j / n_batches: 50 / 590 Cost: 0.11681594 error: 0.028
# j / n_batches: 60 / 590 Cost: 0.12291976 error: 0.031
# j / n_batches: 70 / 590 Cost: 0.15654613 error: 0.03
# j / n_batches: 80 / 590 Cost: 0.11155452 error: 0.029
# j / n_batches: 90 / 590 Cost: 0.14137079 error: 0.035
# j / n_batches: 100 / 590 Cost: 0.16549483 error: 0.042
# j / n_batches: 110 / 590 Cost: 0.112012014 error: 0.026
# j / n_batches: 120 / 590 Cost: 0.117336944 error: 0.028
# j / n_batches: 130 / 590 Cost: 0.12277124 error: 0.031
# j / n_batches: 140 / 590 Cost: 0.1344875 error: 0.034
# j / n_batches: 150 / 590 Cost: 0.13425824 error: 0.031
# j / n_batches: 160 / 590 Cost: 0.11126525 error: 0.028
# j / n_batches: 170 / 590 Cost: 0.12777647 error: 0.038
# j / n_batches: 180 / 590 Cost: 0.10019537 error: 0.032
# j / n_batches: 190 / 590 Cost: 0.12459004 error: 0.036
# j / n_batches: 200 / 590 Cost: 0.10713177 error: 0.031
# j / n_batches: 210 / 590 Cost: 0.15409286 error: 0.043
# j / n_batches: 220 / 590 Cost: 0.1283541 error: 0.036
# j / n_batches: 230 / 590 Cost: 0.115743004 error: 0.029
# j / n_batches: 240 / 590 Cost: 0.11471265 error: 0.029
# j / n_batches: 250 / 590 Cost: 0.1323288 error: 0.03
# j / n_batches: 260 / 590 Cost: 0.10907406 error: 0.023
# j / n_batches: 270 / 590 Cost: 0.09974469 error: 0.024
# j / n_batches: 280 / 590 Cost: 0.11826628 error: 0.029
# j / n_batches: 290 / 590 Cost: 0.13491684 error: 0.029
# j / n_batches: 300 / 590 Cost: 0.14459898 error: 0.031
# j / n_batches: 310 / 590 Cost: 0.14076482 error: 0.034
# j / n_batches: 320 / 590 Cost: 0.09817257 error: 0.023
# j / n_batches: 330 / 590 Cost: 0.08671266 error: 0.025
# j / n_batches: 340 / 590 Cost: 0.09112979 error: 0.027
# j / n_batches: 350 / 590 Cost: 0.110118575 error: 0.03
# j / n_batches: 360 / 590 Cost: 0.10310722 error: 0.03
# j / n_batches: 370 / 590 Cost: 0.123686895 error: 0.035
# j / n_batches: 380 / 590 Cost: 0.13690071 error: 0.035
# j / n_batches: 390 / 590 Cost: 0.15165193 error: 0.043
# j / n_batches: 400 / 590 Cost: 0.11515099 error: 0.029
# j / n_batches: 410 / 590 Cost: 0.1138636 error: 0.031
# j / n_batches: 420 / 590 Cost: 0.11115109 error: 0.03
# j / n_batches: 430 / 590 Cost: 0.12320099 error: 0.033
# j / n_batches: 440 / 590 Cost: 0.111494295 error: 0.032
# j / n_batches: 450 / 590 Cost: 0.119017206 error: 0.027
# j / n_batches: 460 / 590 Cost: 0.10498304 error: 0.024
# j / n_batches: 470 / 590 Cost: 0.106505856 error: 0.029
# j / n_batches: 480 / 590 Cost: 0.093254074 error: 0.024
# j / n_batches: 490 / 590 Cost: 0.086777546 error: 0.026
# j / n_batches: 500 / 590 Cost: 0.1188003 error: 0.027
# j / n_batches: 510 / 590 Cost: 0.1273075 error: 0.035
# j / n_batches: 520 / 590 Cost: 0.13787097 error: 0.041
# j / n_batches: 530 / 590 Cost: 0.13765462 error: 0.038
# j / n_batches: 540 / 590 Cost: 0.16622892 error: 0.037
# j / n_batches: 550 / 590 Cost: 0.12213966 error: 0.031
# j / n_batches: 560 / 590 Cost: 0.12150996 error: 0.029
# j / n_batches: 570 / 590 Cost: 0.13139634 error: 0.037
# j / n_batches: 580 / 590 Cost: 0.117900565 error: 0.034
