# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/Lazy courses/DS:Deep Learning in Python/Digit Recognizer')

# %%
from __future__ import print_function, division
from builtins import range

import numpy as np
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

from util import get_normalized_data, error_rate, cost, y2indicator
from mlp import forward, derivative_w2, derivative_w1, derivative_b2, derivative_b1


def main():
    max_iter = 20 # make it 30 for sigmoid
    print_period = 10

    Xtrain, Xtest, Ytrain, Ytest = get_normalized_data()
    lr = 0.00004
    reg = 0.01

    Ytrain_ind = y2indicator(Ytrain)
    Ytest_ind = y2indicator(Ytest)

    N, D = Xtrain.shape
    batch_sz = 500
    n_batches = N // batch_sz

    M = 300
    K = 10
    W1 = np.random.randn(D, M) / np.sqrt(D)
    b1 = np.zeros(M)
    W2 = np.random.randn(M, K) / np.sqrt(M)
    b2 = np.zeros(K)

    # 1. const
    # cost = -16
    LL_batch = []
    CR_batch = []
    for i in range(max_iter):
        for j in range(n_batches):
            Xbatch = Xtrain[j*batch_sz:(j*batch_sz + batch_sz),]
            Ybatch = Ytrain_ind[j*batch_sz:(j*batch_sz + batch_sz),]
            pYbatch, Z = forward(Xbatch, W1, b1, W2, b2)
            # print "first batch cost:", cost(pYbatch, Ybatch)

            # updates
            W2 -= lr*(derivative_w2(Z, Ybatch, pYbatch) + reg*W2)
            b2 -= lr*(derivative_b2(Ybatch, pYbatch) + reg*b2)
            W1 -= lr*(derivative_w1(Xbatch, Z, Ybatch, pYbatch, W2) + reg*W1)
            b1 -= lr*(derivative_b1(Z, Ybatch, pYbatch, W2) + reg*b1)

            if j % print_period == 0:
                # calculate just for LL
                pY, _ = forward(Xtest, W1, b1, W2, b2)
                # print "pY:", pY
                ll = cost(pY, Ytest_ind)
                LL_batch.append(ll)
                print("Cost at iteration i=%d, j=%d: %.6f" % (i, j, ll))

                err = error_rate(pY, Ytest)
                CR_batch.append(err)
                print("Error rate:", err)

    pY, _ = forward(Xtest, W1, b1, W2, b2)
    print("Final error rate:", error_rate(pY, Ytest))


    # 2. RMSprop
    W1 = np.random.randn(D, M) / np.sqrt(D)
    b1 = np.zeros(M)
    W2 = np.random.randn(M, K) / np.sqrt(M)
    b2 = np.zeros(K)
    LL_rms = []
    CR_rms = []
    lr0 = 0.001 # if set too high we might get NaN!
    cache_W2 = 1
    cache_b2 = 1
    cache_W1 = 1
    cache_b1 = 1
    decay_rate = 0.999
    eps = 1e-10
    for i in range(max_iter):
        for j in range(n_batches):
            Xbatch = Xtrain[j*batch_sz:(j*batch_sz + batch_sz),]
            Ybatch = Ytrain_ind[j*batch_sz:(j*batch_sz + batch_sz),]
            pYbatch, Z = forward(Xbatch, W1, b1, W2, b2)
            # print "first batch cost:", cost(pYbatch, Ybatch)

            # updates
            gW2 = derivative_w2(Z, Ybatch, pYbatch) + reg*W2
            cache_W2 = decay_rate*cache_W2 + (1 - decay_rate)*gW2*gW2
            W2 -= lr0 * gW2 / (np.sqrt(cache_W2) + eps)

            gb2 = derivative_b2(Ybatch, pYbatch) + reg*b2
            cache_b2 = decay_rate*cache_b2 + (1 - decay_rate)*gb2*gb2
            b2 -= lr0 * gb2 / (np.sqrt(cache_b2) + eps)

            gW1 = derivative_w1(Xbatch, Z, Ybatch, pYbatch, W2) + reg*W1
            cache_W1 = decay_rate*cache_W1 + (1 - decay_rate)*gW1*gW1
            W1 -= lr0 * gW1 / (np.sqrt(cache_W1) + eps)

            gb1 = derivative_b1(Z, Ybatch, pYbatch, W2) + reg*b1
            cache_b1 = decay_rate*cache_b1 + (1 - decay_rate)*gb1*gb1
            b1 -= lr0 * gb1 / (np.sqrt(cache_b1) + eps)

            if j % print_period == 0:
                # calculate just for LL
                pY, _ = forward(Xtest, W1, b1, W2, b2)
                # print "pY:", pY
                ll = cost(pY, Ytest_ind)
                LL_rms.append(ll)
                print("Cost at iteration i=%d, j=%d: %.6f" % (i, j, ll))

                err = error_rate(pY, Ytest)
                CR_rms.append(err)
                print("Error rate:", err)

    pY, _ = forward(Xtest, W1, b1, W2, b2)
    print("Final error rate:", error_rate(pY, Ytest))

    plt.plot(LL_batch, label='const')
    plt.plot(LL_rms, label='rms')
    plt.legend()
    plt.show()


if __name__ == '__main__':
    main()
# Out:
# Reading in and transforming data
# Cost at iteration i=0, j=0: 2364.853557
# Error rate: 0.852
# Cost at iteration i=0, j=10: 1817.135872
# Error rate: 0.525
# Cost at iteration i=0, j=20: 1463.753119
# Error rate: 0.352
# Cost at iteration i=0, j=30: 1226.883263
# Error rate: 0.275
# Cost at iteration i=0, j=40: 1061.003050
# Error rate: 0.233
# Cost at iteration i=0, j=50: 943.250249
# Error rate: 0.219
# Cost at iteration i=0, j=60: 851.926263
# Error rate: 0.205
# Cost at iteration i=0, j=70: 781.990677
# Error rate: 0.193
# Cost at iteration i=0, j=80: 724.464802
# Error rate: 0.177
# Cost at iteration i=1, j=0: 715.635660
# Error rate: 0.177
# Cost at iteration i=1, j=10: 669.238737
# Error rate: 0.169
# Cost at iteration i=1, j=20: 631.571394
# Error rate: 0.153
# Cost at iteration i=1, j=30: 598.110260
# Error rate: 0.146
# Cost at iteration i=1, j=40: 570.389213
# Error rate: 0.137
# Cost at iteration i=1, j=50: 545.896912
# Error rate: 0.135
# Cost at iteration i=1, j=60: 524.133867
# Error rate: 0.128
# Cost at iteration i=1, j=70: 506.329705
# Error rate: 0.12
# Cost at iteration i=1, j=80: 488.955551
# Error rate: 0.116
# Cost at iteration i=2, j=0: 486.849459
# Error rate: 0.115
# Cost at iteration i=2, j=10: 471.815217
# Error rate: 0.116
# Cost at iteration i=2, j=20: 458.448065
# Error rate: 0.115
# Cost at iteration i=2, j=30: 445.040532
# Error rate: 0.112
# Cost at iteration i=2, j=40: 434.060973
# Error rate: 0.108
# Cost at iteration i=2, j=50: 423.612761
# Error rate: 0.106
# Cost at iteration i=2, j=60: 413.482102
# Error rate: 0.104
# Cost at iteration i=2, j=70: 405.504519
# Error rate: 0.104
# Cost at iteration i=2, j=80: 396.790513
# Error rate: 0.104
# Cost at iteration i=3, j=0: 396.187280
# Error rate: 0.104
# Cost at iteration i=3, j=10: 388.867597
# Error rate: 0.103
# Cost at iteration i=3, j=20: 381.894546
# Error rate: 0.099
# Cost at iteration i=3, j=30: 374.313025
# Error rate: 0.101
# Cost at iteration i=3, j=40: 368.497701
# Error rate: 0.098
# Cost at iteration i=3, j=50: 362.655736
# Error rate: 0.097
# Cost at iteration i=3, j=60: 356.563953
# Error rate: 0.096
# Cost at iteration i=3, j=70: 352.165010
# Error rate: 0.094
# Cost at iteration i=3, j=80: 346.674789
# Error rate: 0.091
# Cost at iteration i=4, j=0: 346.591947
# Error rate: 0.091
# Cost at iteration i=4, j=10: 342.216814
# Error rate: 0.091
# Cost at iteration i=4, j=20: 337.814509
# Error rate: 0.092
# Cost at iteration i=4, j=30: 332.712836
# Error rate: 0.09
# Cost at iteration i=4, j=40: 329.192346
# Error rate: 0.089
# Cost at iteration i=4, j=50: 325.352163
# Error rate: 0.089
# Cost at iteration i=4, j=60: 321.094903
# Error rate: 0.087
# Cost at iteration i=4, j=70: 318.367706
# Error rate: 0.085
# Cost at iteration i=4, j=80: 314.540647
# Error rate: 0.083
# Cost at iteration i=5, j=0: 314.677975
# Error rate: 0.083
# Cost at iteration i=5, j=10: 311.773295
# Error rate: 0.083
# Cost at iteration i=5, j=20: 308.646571
# Error rate: 0.082
# Cost at iteration i=5, j=30: 304.771615
# Error rate: 0.082
# Cost at iteration i=5, j=40: 302.393334
# Error rate: 0.083
# Cost at iteration i=5, j=50: 299.653328
# Error rate: 0.083
# Cost at iteration i=5, j=60: 296.438111
# Error rate: 0.082
# Cost at iteration i=5, j=70: 294.574091
# Error rate: 0.083
# Cost at iteration i=5, j=80: 291.719518
# Error rate: 0.08
# Cost at iteration i=6, j=0: 291.953004
# Error rate: 0.081
# Cost at iteration i=6, j=10: 289.827978
# Error rate: 0.084
# Cost at iteration i=6, j=20: 287.419665
# Error rate: 0.083
# Cost at iteration i=6, j=30: 284.281126
# Error rate: 0.082
# Cost at iteration i=6, j=40: 282.551299
# Error rate: 0.085
# Cost at iteration i=6, j=50: 280.449874
# Error rate: 0.083
# Cost at iteration i=6, j=60: 277.880256
# Error rate: 0.08
# Cost at iteration i=6, j=70: 276.503889
# Error rate: 0.08
# Cost at iteration i=6, j=80: 274.261399
# Error rate: 0.079
# Cost at iteration i=7, j=0: 274.535578
# Error rate: 0.079
# Cost at iteration i=7, j=10: 272.920058
# Error rate: 0.08
# Cost at iteration i=7, j=20: 270.957489
# Error rate: 0.08
# Cost at iteration i=7, j=30: 268.332003
# Error rate: 0.078
# Cost at iteration i=7, j=40: 267.047726
# Error rate: 0.08
# Cost at iteration i=7, j=50: 265.361264
# Error rate: 0.078
# Cost at iteration i=7, j=60: 263.244333
# Error rate: 0.077
# Cost at iteration i=7, j=70: 262.171534
# Error rate: 0.075
# Cost at iteration i=7, j=80: 260.346629
# Error rate: 0.078
# Cost at iteration i=8, j=0: 260.652794
# Error rate: 0.076
# Cost at iteration i=8, j=10: 259.349704
# Error rate: 0.076
# Cost at iteration i=8, j=20: 257.696044
# Error rate: 0.077
# Cost at iteration i=8, j=30: 255.443431
# Error rate: 0.076
# Cost at iteration i=8, j=40: 254.427850
# Error rate: 0.075
# Cost at iteration i=8, j=50: 253.038054
# Error rate: 0.075
# Cost at iteration i=8, j=60: 251.229064
# Error rate: 0.071
# Cost at iteration i=8, j=70: 250.355113
# Error rate: 0.072
# Cost at iteration i=8, j=80: 248.826369
# Error rate: 0.074
# Cost at iteration i=9, j=0: 249.141170
# Error rate: 0.074
# Cost at iteration i=9, j=10: 248.044710
# Error rate: 0.071
# Cost at iteration i=9, j=20: 246.618882
# Error rate: 0.073
# Cost at iteration i=9, j=30: 244.656288
# Error rate: 0.071
# Cost at iteration i=9, j=40: 243.846340
# Error rate: 0.07
# Cost at iteration i=9, j=50: 242.671807
# Error rate: 0.071
# Cost at iteration i=9, j=60: 241.114206
# Error rate: 0.07
# Cost at iteration i=9, j=70: 240.408514
# Error rate: 0.069
# Cost at iteration i=9, j=80: 239.106765
# Error rate: 0.071
# Cost at iteration i=10, j=0: 239.423830
# Error rate: 0.07
# Cost at iteration i=10, j=10: 238.490058
# Error rate: 0.07
# Cost at iteration i=10, j=20: 237.223960
# Error rate: 0.07
# Cost at iteration i=10, j=30: 235.481513
# Error rate: 0.068
# Cost at iteration i=10, j=40: 234.809601
# Error rate: 0.07
# Cost at iteration i=10, j=50: 233.779097
# Error rate: 0.068
# Cost at iteration i=10, j=60: 232.402337
# Error rate: 0.068
# Cost at iteration i=10, j=70: 231.801853
# Error rate: 0.068
# Cost at iteration i=10, j=80: 230.678852
# Error rate: 0.069
# Cost at iteration i=11, j=0: 230.992259
# Error rate: 0.069
# Cost at iteration i=11, j=10: 230.175769
# Error rate: 0.068
# Cost at iteration i=11, j=20: 229.040254
# Error rate: 0.069
# Cost at iteration i=11, j=30: 227.486809
# Error rate: 0.068
# Cost at iteration i=11, j=40: 226.923049
# Error rate: 0.069
# Cost at iteration i=11, j=50: 226.016808
# Error rate: 0.067
# Cost at iteration i=11, j=60: 224.787950
# Error rate: 0.066
# Cost at iteration i=11, j=70: 224.269774
# Error rate: 0.066
# Cost at iteration i=11, j=80: 223.300595
# Error rate: 0.067
# Cost at iteration i=12, j=0: 223.614642
# Error rate: 0.067
# Cost at iteration i=12, j=10: 222.894115
# Error rate: 0.068
# Cost at iteration i=12, j=20: 221.877311
# Error rate: 0.068
# Cost at iteration i=12, j=30: 220.491429
# Error rate: 0.067
# Cost at iteration i=12, j=40: 220.021010
# Error rate: 0.066
# Cost at iteration i=12, j=50: 219.204416
# Error rate: 0.067
# Cost at iteration i=12, j=60: 218.104028
# Error rate: 0.066
# Cost at iteration i=12, j=70: 217.642691
# Error rate: 0.066
# Cost at iteration i=12, j=80: 216.774969
# Error rate: 0.066
# Cost at iteration i=13, j=0: 217.084419
# Error rate: 0.066
# Cost at iteration i=13, j=10: 216.417928
# Error rate: 0.067
# Cost at iteration i=13, j=20: 215.480561
# Error rate: 0.066
# Cost at iteration i=13, j=30: 214.237602
# Error rate: 0.066
# Cost at iteration i=13, j=40: 213.851521
# Error rate: 0.065
# Cost at iteration i=13, j=50: 213.096535
# Error rate: 0.065
# Cost at iteration i=13, j=60: 212.091668
# Error rate: 0.065
# Cost at iteration i=13, j=70: 211.671790
# Error rate: 0.065
# Cost at iteration i=13, j=80: 210.886728
# Error rate: 0.065
# Cost at iteration i=14, j=0: 211.185299
# Error rate: 0.065
# Cost at iteration i=14, j=10: 210.570295
# Error rate: 0.065
# Cost at iteration i=14, j=20: 209.698376
# Error rate: 0.065
# Cost at iteration i=14, j=30: 208.581574
# Error rate: 0.064
# Cost at iteration i=14, j=40: 208.259578
# Error rate: 0.064
# Cost at iteration i=14, j=50: 207.554646
# Error rate: 0.064
# Cost at iteration i=14, j=60: 206.644136
# Error rate: 0.064
# Cost at iteration i=14, j=70: 206.272957
# Error rate: 0.064
# Cost at iteration i=14, j=80: 205.563334
# Error rate: 0.064
# Cost at iteration i=15, j=0: 205.852191
# Error rate: 0.064
# Cost at iteration i=15, j=10: 205.282487
# Error rate: 0.062
# Cost at iteration i=15, j=20: 204.472597
# Error rate: 0.064
# Cost at iteration i=15, j=30: 203.468683
# Error rate: 0.064
# Cost at iteration i=15, j=40: 203.192363
# Error rate: 0.064
# Cost at iteration i=15, j=50: 202.535127
# Error rate: 0.064
# Cost at iteration i=15, j=60: 201.716275
# Error rate: 0.063
# Cost at iteration i=15, j=70: 201.382794
# Error rate: 0.062
# Cost at iteration i=15, j=80: 200.754587
# Error rate: 0.062
# Cost at iteration i=16, j=0: 201.039209
# Error rate: 0.062
# Cost at iteration i=16, j=10: 200.494557
# Error rate: 0.062
# Cost at iteration i=16, j=20: 199.738786
# Error rate: 0.062
# Cost at iteration i=16, j=30: 198.845528
# Error rate: 0.062
# Cost at iteration i=16, j=40: 198.612065
# Error rate: 0.063
# Cost at iteration i=16, j=50: 197.990081
# Error rate: 0.062
# Cost at iteration i=16, j=60: 197.244701
# Error rate: 0.062
# Cost at iteration i=16, j=70: 196.933845
# Error rate: 0.062
# Cost at iteration i=16, j=80: 196.355995
# Error rate: 0.062
# Cost at iteration i=17, j=0: 196.630859
# Error rate: 0.062
# Cost at iteration i=17, j=10: 196.111963
# Error rate: 0.061
# Cost at iteration i=17, j=20: 195.399684
# Error rate: 0.062
# Cost at iteration i=17, j=30: 194.571953
# Error rate: 0.061
# Cost at iteration i=17, j=40: 194.385073
# Error rate: 0.061
# Cost at iteration i=17, j=50: 193.783915
# Error rate: 0.062
# Cost at iteration i=17, j=60: 193.106157
# Error rate: 0.062
# Cost at iteration i=17, j=70: 192.804645
# Error rate: 0.061
# Cost at iteration i=17, j=80: 192.274103
# Error rate: 0.06
# Cost at iteration i=18, j=0: 192.542798
# Error rate: 0.06
# Cost at iteration i=18, j=10: 192.045625
# Error rate: 0.061
# Cost at iteration i=18, j=20: 191.372867
# Error rate: 0.061
# Cost at iteration i=18, j=30: 190.602301
# Error rate: 0.061
# Cost at iteration i=18, j=40: 190.463129
# Error rate: 0.061
# Cost at iteration i=18, j=50: 189.888565
# Error rate: 0.059
# Cost at iteration i=18, j=60: 189.267236
# Error rate: 0.06
# Cost at iteration i=18, j=70: 188.975465
# Error rate: 0.06
# Cost at iteration i=18, j=80: 188.481005
# Error rate: 0.061
# Cost at iteration i=19, j=0: 188.742805
# Error rate: 0.06
# Cost at iteration i=19, j=10: 188.272546
# Error rate: 0.06
# Cost at iteration i=19, j=20: 187.631394
# Error rate: 0.061
# Cost at iteration i=19, j=30: 186.919463
# Error rate: 0.062
# Cost at iteration i=19, j=40: 186.813713
# Error rate: 0.059
# Cost at iteration i=19, j=50: 186.256172
# Error rate: 0.058
# Cost at iteration i=19, j=60: 185.696271
# Error rate: 0.057
# Cost at iteration i=19, j=70: 185.423233
# Error rate: 0.057
# Cost at iteration i=19, j=80: 184.957826
# Error rate: 0.057
# Final error rate: 0.058
# Cost at iteration i=0, j=0: 1523.269533
# Error rate: 0.478
# Cost at iteration i=0, j=10: 387.012874
# Error rate: 0.109
# Cost at iteration i=0, j=20: 303.379202
# Error rate: 0.091
# Cost at iteration i=0, j=30: 264.339019
# Error rate: 0.077
# Cost at iteration i=0, j=40: 245.298090
# Error rate: 0.074
# Cost at iteration i=0, j=50: 233.225104
# Error rate: 0.059
# Cost at iteration i=0, j=60: 216.628528
# Error rate: 0.06
# Cost at iteration i=0, j=70: 207.069429
# Error rate: 0.06
# Cost at iteration i=0, j=80: 202.302764
# Error rate: 0.056
# Cost at iteration i=1, j=0: 206.364813
# Error rate: 0.056
# Cost at iteration i=1, j=10: 193.848232
# Error rate: 0.053
# Cost at iteration i=1, j=20: 185.095182
# Error rate: 0.047
# Cost at iteration i=1, j=30: 180.845254
# Error rate: 0.05
# Cost at iteration i=1, j=40: 186.143091
# Error rate: 0.056
# Cost at iteration i=1, j=50: 173.495283
# Error rate: 0.046
# Cost at iteration i=1, j=60: 169.043674
# Error rate: 0.048
# Cost at iteration i=1, j=70: 159.972812
# Error rate: 0.045
# Cost at iteration i=1, j=80: 159.329779
# Error rate: 0.043
# Cost at iteration i=2, j=0: 163.203238
# Error rate: 0.048
# Cost at iteration i=2, j=10: 153.119231
# Error rate: 0.041
# Cost at iteration i=2, j=20: 152.781055
# Error rate: 0.044
# Cost at iteration i=2, j=30: 151.447709
# Error rate: 0.042
# Cost at iteration i=2, j=40: 156.117410
# Error rate: 0.046
# Cost at iteration i=2, j=50: 143.134617
# Error rate: 0.04
# Cost at iteration i=2, j=60: 144.304619
# Error rate: 0.042
# Cost at iteration i=2, j=70: 135.556746
# Error rate: 0.039
# Cost at iteration i=2, j=80: 135.256150
# Error rate: 0.037
# Cost at iteration i=3, j=0: 139.253458
# Error rate: 0.04
# Cost at iteration i=3, j=10: 132.508258
# Error rate: 0.038
# Cost at iteration i=3, j=20: 133.315956
# Error rate: 0.041
# Cost at iteration i=3, j=30: 132.612136
# Error rate: 0.039
# Cost at iteration i=3, j=40: 139.024466
# Error rate: 0.04
# Cost at iteration i=3, j=50: 130.029695
# Error rate: 0.037
# Cost at iteration i=3, j=60: 130.694304
# Error rate: 0.036
# Cost at iteration i=3, j=70: 122.364383
# Error rate: 0.032
# Cost at iteration i=3, j=80: 123.908577
# Error rate: 0.036
# Cost at iteration i=4, j=0: 127.733719
# Error rate: 0.038
# Cost at iteration i=4, j=10: 121.737108
# Error rate: 0.035
# Cost at iteration i=4, j=20: 121.111280
# Error rate: 0.036
# Cost at iteration i=4, j=30: 124.230933
# Error rate: 0.038
# Cost at iteration i=4, j=40: 128.411202
# Error rate: 0.038
# Cost at iteration i=4, j=50: 122.209899
# Error rate: 0.035
# Cost at iteration i=4, j=60: 122.155142
# Error rate: 0.034
# Cost at iteration i=4, j=70: 112.406132
# Error rate: 0.031
# Cost at iteration i=4, j=80: 113.102802
# Error rate: 0.033
# Cost at iteration i=5, j=0: 116.751225
# Error rate: 0.031
# Cost at iteration i=5, j=10: 112.395101
# Error rate: 0.029
# Cost at iteration i=5, j=20: 112.918745
# Error rate: 0.034
# Cost at iteration i=5, j=30: 112.658432
# Error rate: 0.033
# Cost at iteration i=5, j=40: 120.547081
# Error rate: 0.039
# Cost at iteration i=5, j=50: 115.501078
# Error rate: 0.032
# Cost at iteration i=5, j=60: 115.899261
# Error rate: 0.03
# Cost at iteration i=5, j=70: 106.457649
# Error rate: 0.024
# Cost at iteration i=5, j=80: 108.082829
# Error rate: 0.028
# Cost at iteration i=6, j=0: 111.129621
# Error rate: 0.026
# Cost at iteration i=6, j=10: 107.597378
# Error rate: 0.026
# Cost at iteration i=6, j=20: 107.601375
# Error rate: 0.03
# Cost at iteration i=6, j=30: 107.433095
# Error rate: 0.032
# Cost at iteration i=6, j=40: 115.046169
# Error rate: 0.036
# Cost at iteration i=6, j=50: 111.292023
# Error rate: 0.032
# Cost at iteration i=6, j=60: 111.452865
# Error rate: 0.026
# Cost at iteration i=6, j=70: 102.674577
# Error rate: 0.023
# Cost at iteration i=6, j=80: 104.709335
# Error rate: 0.027
# Cost at iteration i=7, j=0: 106.953771
# Error rate: 0.025
# Cost at iteration i=7, j=10: 104.433909
# Error rate: 0.027
# Cost at iteration i=7, j=20: 104.317755
# Error rate: 0.028
# Cost at iteration i=7, j=30: 104.022988
# Error rate: 0.03
# Cost at iteration i=7, j=40: 111.025072
# Error rate: 0.031
# Cost at iteration i=7, j=50: 108.813815
# Error rate: 0.03
# Cost at iteration i=7, j=60: 107.870511
# Error rate: 0.025
# Cost at iteration i=7, j=70: 100.395519
# Error rate: 0.024
# Cost at iteration i=7, j=80: 102.827553
# Error rate: 0.027
# Cost at iteration i=8, j=0: 104.684651
# Error rate: 0.026
# Cost at iteration i=8, j=10: 102.758678
# Error rate: 0.027
# Cost at iteration i=8, j=20: 102.479828
# Error rate: 0.026
# Cost at iteration i=8, j=30: 101.680928
# Error rate: 0.029
# Cost at iteration i=8, j=40: 107.869820
# Error rate: 0.029
# Cost at iteration i=8, j=50: 106.891282
# Error rate: 0.027
# Cost at iteration i=8, j=60: 105.298757
# Error rate: 0.022
# Cost at iteration i=8, j=70: 98.587147
# Error rate: 0.022
# Cost at iteration i=8, j=80: 101.442419
# Error rate: 0.026
# Cost at iteration i=9, j=0: 103.052977
# Error rate: 0.025
# Cost at iteration i=9, j=10: 101.675842
# Error rate: 0.026
# Cost at iteration i=9, j=20: 101.693868
# Error rate: 0.024
# Cost at iteration i=9, j=30: 100.189251
# Error rate: 0.027
# Cost at iteration i=9, j=40: 105.908707
# Error rate: 0.028
# Cost at iteration i=9, j=50: 105.861634
# Error rate: 0.027
# Cost at iteration i=9, j=60: 103.601450
# Error rate: 0.02
# Cost at iteration i=9, j=70: 98.023207
# Error rate: 0.021
# Cost at iteration i=9, j=80: 100.911287
# Error rate: 0.025
# Cost at iteration i=10, j=0: 102.306497
# Error rate: 0.024
# Cost at iteration i=10, j=10: 101.566975
# Error rate: 0.025
# Cost at iteration i=10, j=20: 101.168108
# Error rate: 0.023
# Cost at iteration i=10, j=30: 99.320090
# Error rate: 0.027
# Cost at iteration i=10, j=40: 104.339328
# Error rate: 0.023
# Cost at iteration i=10, j=50: 105.047059
# Error rate: 0.026
# Cost at iteration i=10, j=60: 102.596984
# Error rate: 0.019
# Cost at iteration i=10, j=70: 97.422007
# Error rate: 0.021
# Cost at iteration i=10, j=80: 100.767547
# Error rate: 0.024
# Cost at iteration i=11, j=0: 102.001398
# Error rate: 0.024
# Cost at iteration i=11, j=10: 101.615483
# Error rate: 0.024
# Cost at iteration i=11, j=20: 101.183313
# Error rate: 0.02
# Cost at iteration i=11, j=30: 98.856288
# Error rate: 0.025
# Cost at iteration i=11, j=40: 103.716412
# Error rate: 0.023
# Cost at iteration i=11, j=50: 104.748515
# Error rate: 0.025
# Cost at iteration i=11, j=60: 102.116380
# Error rate: 0.019
# Cost at iteration i=11, j=70: 97.182537
# Error rate: 0.02
# Cost at iteration i=11, j=80: 100.645487
# Error rate: 0.022
# Cost at iteration i=12, j=0: 101.733364
# Error rate: 0.023
# Cost at iteration i=12, j=10: 101.606481
# Error rate: 0.023
# Cost at iteration i=12, j=20: 101.046380
# Error rate: 0.021
# Cost at iteration i=12, j=30: 98.518653
# Error rate: 0.024
# Cost at iteration i=12, j=40: 103.004979
# Error rate: 0.022
# Cost at iteration i=12, j=50: 104.575039
# Error rate: 0.024
# Cost at iteration i=12, j=60: 101.792992
# Error rate: 0.019
# Cost at iteration i=12, j=70: 97.077820
# Error rate: 0.02
# Cost at iteration i=12, j=80: 100.657813
# Error rate: 0.021
# Cost at iteration i=13, j=0: 101.823795
# Error rate: 0.02
# Cost at iteration i=13, j=10: 101.914715
# Error rate: 0.023
# Cost at iteration i=13, j=20: 101.311976
# Error rate: 0.02
# Cost at iteration i=13, j=30: 98.493125
# Error rate: 0.021
# Cost at iteration i=13, j=40: 102.651139
# Error rate: 0.022
# Cost at iteration i=13, j=50: 105.420514
# Error rate: 0.022
# Cost at iteration i=13, j=60: 101.809276
# Error rate: 0.018
# Cost at iteration i=13, j=70: 97.396341
# Error rate: 0.02
# Cost at iteration i=13, j=80: 100.476530
# Error rate: 0.021
# Cost at iteration i=14, j=0: 101.782242
# Error rate: 0.021
# Cost at iteration i=14, j=10: 103.874213
# Error rate: 0.024
# Cost at iteration i=14, j=20: 101.028646
# Error rate: 0.02
# Cost at iteration i=14, j=30: 98.660221
# Error rate: 0.023
# Cost at iteration i=14, j=40: 104.218714
# Error rate: 0.023
# Cost at iteration i=14, j=50: 104.835712
# Error rate: 0.022
# Cost at iteration i=14, j=60: 102.182159
# Error rate: 0.019
# Cost at iteration i=14, j=70: 97.866011
# Error rate: 0.02
# Cost at iteration i=14, j=80: 101.410671
# Error rate: 0.02
# Cost at iteration i=15, j=0: 102.346777
# Error rate: 0.022
# Cost at iteration i=15, j=10: 102.774852
# Error rate: 0.022
# Cost at iteration i=15, j=20: 101.977680
# Error rate: 0.02
# Cost at iteration i=15, j=30: 98.902117
# Error rate: 0.022
# Cost at iteration i=15, j=40: 102.295678
# Error rate: 0.02
# Cost at iteration i=15, j=50: 104.423557
# Error rate: 0.022
# Cost at iteration i=15, j=60: 101.901717
# Error rate: 0.019
# Cost at iteration i=15, j=70: 97.801926
# Error rate: 0.021
# Cost at iteration i=15, j=80: 101.071065
# Error rate: 0.021
# Cost at iteration i=16, j=0: 102.017182
# Error rate: 0.021
# Cost at iteration i=16, j=10: 102.595370
# Error rate: 0.021
# Cost at iteration i=16, j=20: 102.140828
# Error rate: 0.02
# Cost at iteration i=16, j=30: 99.087131
# Error rate: 0.022
# Cost at iteration i=16, j=40: 102.105724
# Error rate: 0.02
# Cost at iteration i=16, j=50: 104.397533
# Error rate: 0.022
# Cost at iteration i=16, j=60: 102.335593
# Error rate: 0.019
# Cost at iteration i=16, j=70: 98.576519
# Error rate: 0.021
# Cost at iteration i=16, j=80: 101.235221
# Error rate: 0.021
# Cost at iteration i=17, j=0: 102.212468
# Error rate: 0.021
# Cost at iteration i=17, j=10: 102.927199
# Error rate: 0.02
# Cost at iteration i=17, j=20: 102.706074
# Error rate: 0.018
# Cost at iteration i=17, j=30: 99.614063
# Error rate: 0.022
# Cost at iteration i=17, j=40: 102.168339
# Error rate: 0.02
# Cost at iteration i=17, j=50: 104.537225
# Error rate: 0.021
# Cost at iteration i=17, j=60: 102.283299
# Error rate: 0.019
# Cost at iteration i=17, j=70: 99.051390
# Error rate: 0.02
# Cost at iteration i=17, j=80: 101.319279
# Error rate: 0.021
# Cost at iteration i=18, j=0: 102.227422
# Error rate: 0.021
# Cost at iteration i=18, j=10: 103.015951
# Error rate: 0.02
# Cost at iteration i=18, j=20: 102.766048
# Error rate: 0.018
# Cost at iteration i=18, j=30: 99.886423
# Error rate: 0.021
# Cost at iteration i=18, j=40: 102.279959
# Error rate: 0.02
# Cost at iteration i=18, j=50: 104.696634
# Error rate: 0.021
# Cost at iteration i=18, j=60: 102.767829
# Error rate: 0.019
# Cost at iteration i=18, j=70: 99.752706
# Error rate: 0.02
# Cost at iteration i=18, j=80: 101.703072
# Error rate: 0.021
# Cost at iteration i=19, j=0: 102.618779
# Error rate: 0.021
# Cost at iteration i=19, j=10: 103.463502
# Error rate: 0.02
# Cost at iteration i=19, j=20: 103.398288
# Error rate: 0.018
# Cost at iteration i=19, j=30: 100.572604
# Error rate: 0.021
# Cost at iteration i=19, j=40: 102.500910
# Error rate: 0.02
# Cost at iteration i=19, j=50: 105.011443
# Error rate: 0.021
# Cost at iteration i=19, j=60: 103.073161
# Error rate: 0.019
# Cost at iteration i=19, j=70: 100.173750
# Error rate: 0.02
# Cost at iteration i=19, j=80: 101.961172
# Error rate: 0.021
# Final error rate: 0.021
